# %% [markdown]
# # --- Day 21: RPG Simulator 20XX ---
#
# Little Henry Case got a new video game for Christmas. It's an RPG, and he's stuck on a boss. He needs to know what equipment to buy at the shop. He hands you the controller.
#
# In this game, the player (you) and the enemy (the boss) take turns attacking. The player always goes first. Each attack reduces the opponent's hit points by at least 1. The first character at or below 0 hit points loses.
#
# Damage dealt by an attacker each turn is equal to the attacker's damage score minus the defender's armor score. An attacker always does at least 1 damage. So, if the attacker has a damage score of 8, and the defender has an armor score of 3, the defender loses 5 hit points. If the defender had an armor score of 300, the defender would still lose 1 hit point.
#
# Your damage score and armor score both start at zero. They can be increased by buying items in exchange for gold. You start with no items and have as much gold as you need. Your total damage or armor is equal to the sum of those stats from all of your items. You have 100 hit points.
#
# Here is what the item shop is selling:
#
# Weapons:    Cost  Damage  Armor
# - Dagger        8     4       0
# - Shortsword   10     5       0
# - Warhammer    25     6       0
# - Longsword    40     7       0
# - Greataxe     74     8       0
#
# Armor:      Cost  Damage  Armor
# - Leather      13     0       1
# - Chainmail    31     0       2
# - Splintmail   53     0       3
# - Bandedmail   75     0       4
# - Platemail   102     0       5
#
# Rings:      Cost  Damage  Armor
# - Damage +1    25     1       0
# - Damage +2    50     2       0
# - Damage +3   100     3       0
# - Defense +1   20     0       1
# - Defense +2   40     0       2
# - Defense +3   80     0       3
#
# You must buy exactly one weapon; no dual-wielding. Armor is optional, but you can't use more than one. You can buy 0-2 rings (at most one for each hand). You must use any items you buy. The shop only has one of each item, so you can't buy, for example, two rings of Damage +3.
#
# For example, suppose you have 8 hit points, 5 damage, and 5 armor, and that the boss has 12 hit points, 7 damage, and 2 armor:
#
# - The player deals 5-2 = 3 damage; the boss goes down to 9 hit points.
# - The boss deals 7-5 = 2 damage; the player goes down to 6 hit points.
# - The player deals 5-2 = 3 damage; the boss goes down to 6 hit points.
# - The boss deals 7-5 = 2 damage; the player goes down to 4 hit points.
# - The player deals 5-2 = 3 damage; the boss goes down to 3 hit points.
# - The boss deals 7-5 = 2 damage; the player goes down to 2 hit points.
# - The player deals 5-2 = 3 damage; the boss goes down to 0 hit points.
#
# In this scenario, the player wins! (Barely.)
#
# You have 100 hit points. The boss's actual stats are in your puzzle input. What is the least amount of gold you can spend and still win the fight?

# %%
# Write shop inventory as 3 dataframes, each containing their stats. 
# Add an 'empty' slot for armour and two 'empty' slots for rings.
# Add the Boss's starting stats and your own starting stats

import pandas as pd

weaponsIn = {'Name':['Dagger', 'Shortsword', 'Warhammer', 'Longsword', 'Greataxe'], 'Cost':[8,10,25,40,74], 'Damage':[4,5,6,7,8], 'Defense':[0,0,0,0,0]}
weapons = pd.DataFrame(data=weaponsIn)

armorsIn = {'Name':['Empty', 'Leather', 'Chainmail', 'Splintmail', 'Bandedmail', 'Platemail'], 'Cost':[0,13,31,53,75,102], 'Damage':[0,0,0,0,0,0], 'Defense':[0,1,2,3,4,5]}
armors = pd.DataFrame(data=armorsIn)

ringsIn = {'Name':['Empty', 'Empty', 'Damage+1', 'Damage+2', 'Damage+3', 'Defense+1', 'Defense+2', 'Defense+3'], 'Cost':[0,0,25,50,100,20,40,80], 'Damage':[0,0,1,2,3,0,0,0], 'Defense':[0,0,0,0,0,1,2,3]}
rings = pd.DataFrame(data=ringsIn)

Boss = {'HP': 100, 'Damage':8, 'Defense':2}
Jono = {'HP': 100, 'Damage':0, 'Defense':0}

print(weapons)
print(armors)
print(rings)
# Out:
#          Name  Cost  Damage  Defense
# 0      Dagger     8       4        0
# 1  Shortsword    10       5        0
# 2   Warhammer    25       6        0
# 3   Longsword    40       7        0
# 4    Greataxe    74       8        0
#          Name  Cost  Damage  Defense
# 0       Empty     0       0        0
# 1     Leather    13       0        1
# 2   Chainmail    31       0        2
# 3  Splintmail    53       0        3
# 4  Bandedmail    75       0        4
# 5   Platemail   102       0        5
#         Name  Cost  Damage  Defense
# 0      Empty     0       0        0
# 1      Empty     0       0        0
# 2   Damage+1    25       1        0
# 3   Damage+2    50       2        0
# 4   Damage+3   100       3        0
# 5  Defense+1    20       0        1
# 6  Defense+2    40       0        2
# 7  Defense+3    80       0        3

# %%
# Create a new dataframe containing all the possible pairs of rings
import itertools
from numpy import transpose

pairsIn = {}
counter = 0
# Use itertools to find all combinations of two rings and write them to a dictionary
for pair in itertools.combinations(rings.index, 2):
    pairsIn[counter] = [pair[0], pair[1], rings.at[pair[0], 'Cost'] + rings.at[pair[1], 'Cost'], rings.at[pair[0], 'Damage'] + rings.at[pair[1], 'Damage'], rings.at[pair[0], 'Defense'] + rings.at[pair[1], 'Defense']]
    counter += 1
# This method writes each pair as a column, so transpose the output and, 
# for the sake of neatness, sort and reorder the table by ascending cost
pairs = pd.DataFrame(data=pairsIn, index=['Ring 1', 'Ring 2', 'Cost', 'Damage', 'Defense']).T.sort_values(by=['Cost']).reset_index()
del pairs['index']
print(pairs)
# Out:
#     Ring 1  Ring 2  Cost  Damage  Defense
# 0        0       1     0       0        0
# 1        0       5    20       0        1
# 2        1       5    20       0        1
# 3        0       2    25       1        0
# 4        1       2    25       1        0
# 5        0       6    40       0        2
# 6        1       6    40       0        2
# 7        2       5    45       1        1
# 8        0       3    50       2        0
# 9        1       3    50       2        0
# 10       5       6    60       0        3
# 11       2       6    65       1        2
# 12       3       5    70       2        1
# 13       2       3    75       3        0
# 14       1       7    80       0        3
# 15       0       7    80       0        3
# 16       3       6    90       2        2
# 17       1       4   100       3        0
# 18       0       4   100       3        0
# 19       5       7   100       0        4
# 20       2       7   105       1        3
# 21       4       5   120       3        1
# 22       6       7   120       0        5
# 23       2       4   125       4        0
# 24       3       7   130       2        3
# 25       4       6   140       3        2
# 26       3       4   150       5        0
# 27       4       7   180       3        3

# %%
# Create a list of lists reprenting the shop inventory for each type of goods (using ring pairs instead of rings)
shop = []
shop += list(weapons.index), list(armors.index), list(pairs.index)
# Again using itertools, determine all possible combinations of gear and their cost
inventories = []
for x in list(itertools.product(*shop)):
    totalCost = 0
    totalCost = weapons['Cost'][x[0]] + armors['Cost'][x[1]] + pairs['Cost'][x[2]]
    inventories += [[totalCost, x[0], x[1], x[2]]]
# Sort the inventories list by cost
inventories.sort(key = lambda x: x[0])
print(inventories)
# Out:
# [[8, 0, 0, 0], [10, 1, 0, 0], [21, 0, 1, 0], [23, 1, 1, 0], [25, 2, 0, 0], [28, 0, 0, 1], [28, 0, 0, 2], [30, 1, 0, 1], [30, 1, 0, 2], [33, 0, 0, 3], [33, 0, 0, 4], [35, 1, 0, 3], [35, 1, 0, 4], [38, 2, 1, 0], [39, 0, 2, 0], [40, 3, 0, 0], [41, 0, 1, 1], [41, 0, 1, 2], [41, 1, 2, 0], [43, 1, 1, 1], [43, 1, 1, 2], [45, 2, 0, 1], [45, 2, 0, 2], [46, 0, 1, 3], [46, 0, 1, 4], [48, 0, 0, 5], [48, 0, 0, 6], [48, 1, 1, 3], [48, 1, 1, 4], [50, 1, 0, 5], [50, 1, 0, 6], [50, 2, 0, 3], [50, 2, 0, 4], [53, 0, 0, 7], [53, 3, 1, 0], [55, 1, 0, 7], [56, 2, 2, 0], [58, 0, 0, 8], [58, 0, 0, 9], [58, 2, 1, 1], [58, 2, 1, 2], [59, 0, 2, 1], [59, 0, 2, 2], [60, 1, 0, 8], [60, 1, 0, 9], [60, 3, 0, 1], [60, 3, 0, 2], [61, 0, 1, 5], [61, 0, 1, 6], [61, 0, 3, 0], [61, 1, 2, 1], [61, 1, 2, 2], [63, 1, 1, 5], [63, 1, 1, 6], [63, 1, 3, 0], [63, 2, 1, 3], [63, 2, 1, 4], [64, 0, 2, 3], [64, 0, 2, 4], [65, 2, 0, 5], [65, 2, 0, 6], [65, 3, 0, 3], [65, 3, 0, 4], [66, 0, 1, 7], [66, 1, 2, 3], [66, 1, 2, 4], [68, 0, 0, 10], [68, 1, 1, 7], [70, 1, 0, 10], [70, 2, 0, 7], [71, 0, 1, 8], [71, 0, 1, 9], [71, 3, 2, 0], [73, 0, 0, 11], [73, 1, 1, 8], [73, 1, 1, 9], [73, 3, 1, 1], [73, 3, 1, 2], [74, 4, 0, 0], [75, 1, 0, 11], [75, 2, 0, 8], [75, 2, 0, 9], [76, 2, 2, 1], [76, 2, 2, 2], [78, 0, 0, 12], [78, 2, 1, 5], [78, 2, 1, 6], [78, 2, 3, 0], [78, 3, 1, 3], [78, 3, 1, 4], [79, 0, 2, 5], [79, 0, 2, 6], [80, 1, 0, 12], [80, 3, 0, 5], [80, 3, 0, 6], [81, 0, 1, 10], [81, 0, 3, 1], [81, 0, 3, 2], [81, 1, 2, 5], [81, 1, 2, 6], [81, 2, 2, 3], [81, 2, 2, 4], [83, 0, 0, 13], [83, 0, 4, 0], [83, 1, 1, 10], [83, 1, 3, 1], [83, 1, 3, 2], [83, 2, 1, 7], [84, 0, 2, 7], [85, 1, 0, 13], [85, 1, 4, 0], [85, 2, 0, 10], [85, 3, 0, 7], [86, 0, 1, 11], [86, 0, 3, 3], [86, 0, 3, 4], [86, 1, 2, 7], [87, 4, 1, 0], [88, 0, 0, 14], [88, 0, 0, 15], [88, 1, 1, 11], [88, 1, 3, 3], [88, 1, 3, 4], [88, 2, 1, 8], [88, 2, 1, 9], [89, 0, 2, 8], [89, 0, 2, 9], [90, 1, 0, 14], [90, 1, 0, 15], [90, 2, 0, 11], [90, 3, 0, 8], [90, 3, 0, 9], [91, 0, 1, 12], [91, 1, 2, 8], [91, 1, 2, 9], [91, 3, 2, 1], [91, 3, 2, 2], [93, 1, 1, 12], [93, 3, 1, 5], [93, 3, 1, 6], [93, 3, 3, 0], [94, 4, 0, 1], [94, 4, 0, 2], [95, 2, 0, 12], [96, 0, 1, 13], [96, 2, 2, 5], [96, 2, 2, 6], [96, 3, 2, 3], [96, 3, 2, 4], [98, 0, 0, 16], [98, 1, 1, 13], [98, 2, 1, 10], [98, 2, 3, 1], [98, 2, 3, 2], [98, 3, 1, 7], [99, 0, 2, 10], [99, 4, 0, 3], [99, 4, 0, 4], [100, 1, 0, 16], [100, 2, 0, 13], [100, 2, 4, 0], [100, 3, 0, 10], [101, 0, 1, 14], [101, 0, 1, 15], [101, 0, 3, 5], [101, 0, 3, 6], [101, 1, 2, 10], [101, 2, 2, 7], [103, 0, 4, 1], [103, 0, 4, 2], [103, 1, 1, 14], [103, 1, 1, 15], [103, 1, 3, 5], [103, 1, 3, 6], [103, 2, 1, 11], [103, 2, 3, 3], [103, 2, 3, 4], [103, 3, 1, 8], [103, 3, 1, 9], [104, 0, 2, 11], [105, 1, 4, 1], [105, 1, 4, 2], [105, 2, 0, 14], [105, 2, 0, 15], [105, 3, 0, 11], [105, 4, 2, 0], [106, 0, 3, 7], [106, 1, 2, 11], [106, 2, 2, 8], [106, 2, 2, 9], [107, 4, 1, 1], [107, 4, 1, 2], [108, 0, 0, 17], [108, 0, 0, 18], [108, 0, 0, 19], [108, 0, 4, 3], [108, 0, 4, 4], [108, 1, 3, 7], [108, 2, 1, 12], [109, 0, 2, 12], [110, 0, 5, 0], [110, 1, 0, 17], [110, 1, 0, 18], [110, 1, 0, 19], [110, 1, 4, 3], [110, 1, 4, 4], [110, 3, 0, 12], [111, 0, 1, 16], [111, 0, 3, 8], [111, 0, 3, 9], [111, 1, 2, 12], [111, 3, 2, 5], [111, 3, 2, 6], [112, 1, 5, 0], [112, 4, 1, 3], [112, 4, 1, 4], [113, 0, 0, 20], [113, 1, 1, 16], [113, 1, 3, 8], [113, 1, 3, 9], [113, 2, 1, 13], [113, 3, 1, 10], [113, 3, 3, 1], [113, 3, 3, 2], [114, 0, 2, 13], [114, 4, 0, 5], [114, 4, 0, 6], [115, 1, 0, 20], [115, 2, 0, 16], [115, 3, 0, 13], [115, 3, 4, 0], [116, 1, 2, 13], [116, 2, 2, 10], [116, 3, 2, 7], [118, 2, 1, 14], [118, 2, 1, 15], [118, 2, 3, 5], [118, 2, 3, 6], [118, 3, 1, 11], [118, 3, 3, 3], [118, 3, 3, 4], [119, 0, 2, 14], [119, 0, 2, 15], [119, 4, 0, 7], [120, 2, 4, 1], [120, 2, 4, 2], [120, 3, 0, 14], [120, 3, 0, 15], [121, 0, 1, 17], [121, 0, 1, 18], [121, 0, 1, 19], [121, 0, 3, 10], [121, 1, 2, 14], [121, 1, 2, 15], [121, 2, 2, 11], [12 ...

# %%
win = False
loss = False
# Check through the list in order of cheapest to most costly, and simulate the fight
for inventory in inventories:
    # If you won the last fight, stop the simulation
    if win == True:
        break
    else:
        # Reset the values changes in the last fight
        Jono['HP'] = 100
        Boss['HP'] = 100
        loss = False
    # Calculate your Damage and Defense with the new inventory
    Jono['Damage'] = weapons['Damage'][inventory[1]] + pairs['Damage'][inventory[3]]
    Jono['Defense'] = armors['Defense'][inventory[2]] + pairs['Defense'][inventory[3]]
    # Use a while loop to keep going until the fight is either won or lost
    while win == False and loss == False:
        # First, you attack
        if Jono['Damage'] - Boss['Defense'] >= 1:
            Boss['HP'] -= Jono['Damage'] - Boss['Defense']
        else:
            Boss['HP'] -= 1
        # If Boss is reduced to 0 or lower, the fight is won, print out the result
        if Boss['HP'] <= 0:
            win = True
            winningSet = [weapons['Name'][inventory[1]], armors['Name'][inventory[2]], 
                          rings['Name'][pairs['Ring 1'][inventory[3]]], rings['Name'][pairs['Ring 2'][inventory[3]]]]
            print('Jono wins for ', inventory[0], 'with', winningSet)
            break
        # Otherwise the boss attacks
        elif Boss['Damage'] - Jono['Defense'] >= 1:
            Jono['HP'] -= Boss['Damage'] - Jono['Defense']
        else:
            Jono['HP'] -= 1
        # If your health drops to 0 or lower, you lose and this is printed
        if Jono['HP'] <= 0:
            loss = True
            losingSet = [weapons['Name'][inventory[1]], armors['Name'][inventory[2]], 
                         rings['Name'][pairs['Ring 1'][inventory[3]]], rings['Name'][pairs['Ring 2'][inventory[3]]]]
            print('Jono loses with', losingSet)
# Out:
# Jono loses with ['Dagger', 'Empty', 'Empty', 'Empty']
# Jono loses with ['Shortsword', 'Empty', 'Empty', 'Empty']
# Jono loses with ['Dagger', 'Leather', 'Empty', 'Empty']
# Jono loses with ['Shortsword', 'Leather', 'Empty', 'Empty']
# Jono loses with ['Warhammer', 'Empty', 'Empty', 'Empty']
# Jono loses with ['Dagger', 'Empty', 'Empty', 'Defense+1']
# Jono loses with ['Dagger', 'Empty', 'Empty', 'Defense+1']
# Jono loses with ['Shortsword', 'Empty', 'Empty', 'Defense+1']
# Jono loses with ['Shortsword', 'Empty', 'Empty', 'Defense+1']
# Jono loses with ['Dagger', 'Empty', 'Empty', 'Damage+1']
# Jono loses with ['Dagger', 'Empty', 'Empty', 'Damage+1']
# Jono loses with ['Shortsword', 'Empty', 'Empty', 'Damage+1']
# Jono loses with ['Shortsword', 'Empty', 'Empty', 'Damage+1']
# Jono loses with ['Warhammer', 'Leather', 'Empty', 'Empty']
# Jono loses with ['Dagger', 'Chainmail', 'Empty', 'Empty']
# Jono loses with ['Longsword', 'Empty', 'Empty', 'Empty']
# Jono loses with ['Dagger', 'Leather', 'Empty', 'Defense+1']
# Jono loses with ['Dagger', 'Leather', 'Empty', 'Defense+1']
# Jono loses with ['Shortsword', 'Chainmail', 'Empty', 'Empty']
# Jono loses with ['Shortsword', 'Leather', 'Empty', 'Defense+1']
# Jono loses with ['Shortsword', 'Leather', 'Empty', 'Defense+1']
# Jono loses with ['Warhammer', 'Empty', 'Empty', 'Defense+1']
# Jono loses with ['Warhammer', 'Empty', 'Empty', 'Defense+1']
# Jono loses with ['Dagger', 'Leather', 'Empty', 'Damage+1']
# Jono loses with ['Dagger', 'Leather', 'Empty', 'Damage+1']
# Jono loses with ['Dagger', 'Empty', 'Empty', 'Defense+2']
# Jono loses with ['Dagger', 'Empty', 'Empty', 'Defense+2']
# Jono loses with ['Shortsword', 'Leather', 'Empty', 'Damage+1']
# Jono loses with ['Shortsword', 'Leather', 'Empty', 'Damage+1']
# Jono loses with ['Shortsword', 'Empty', 'Empty', 'Defense+2']
# Jono loses with ['Shortsword', 'Empty', 'Empty', 'Defense+2']
# Jono loses with ['Warhammer', 'Empty', 'Empty', 'Damage+1']
# Jono loses with ['Warhammer', 'Empty', 'Empty', 'Damage+1']
# Jono loses with ['Dagger', 'Empty', 'Damage+1', 'Defense+1']
# Jono loses with ['Longsword', 'Leather', 'Empty', 'Empty']
# Jono loses with ['Shortsword', 'Empty', 'Damage+1', 'Defense+1']
# Jono loses with ['Warhammer', 'Chainmail', 'Empty', 'Empty']
# Jono loses with ['Dagger', 'Empty', 'Empty', 'Damage+2']
# Jono loses with ['Dagger', 'Empty', 'Empty', 'Damage+2']
# Jono loses with ['Warhammer', 'Leather', 'Empty', 'Defense+1']
# Jono loses with ['Warhammer', 'Leather', 'Empty', 'Defense+1']
# Jono loses with ['Dagger', 'Chainmail', 'Empty', 'Defense+1']
# Jono loses with ['Dagger', 'Chainmail', 'Empty', 'Defense+1']
# Jono loses with ['Shortsword', 'Empty', 'Empty', 'Damage+2']
# Jono loses with ['Shortsword', 'Empty', 'Empty', 'Damage+2']
# Jono loses with ['Longsword', 'Empty', 'Empty', 'Defense+1']
# Jono loses with ['Longsword', 'Empty', 'Empty', 'Defense+1']
# Jono loses with ['Dagger', 'Leather', 'Empty', 'Defense+2']
# Jono loses with ['Dagger', 'Leather', 'Empty', 'Defense+2']
# Jono loses with ['Dagger', 'Splintmail', 'Empty', 'Empty']
# Jono loses with ['Shortsword', 'Chainmail', 'Empty', 'Defense+1']
# Jono loses with ['Shortsword', 'Chainmail', 'Empty', 'Defense+1']
# Jono loses with ['Shortsword', 'Leather', 'Empty', 'Defense+2']
# Jono loses with ['Shortsword', 'Leather', 'Empty', 'Defense+2']
# Jono loses with ['Shortsword', 'Splintmail', 'Empty', 'Empty']
# Jono loses with ['Warhammer', 'Leather', 'Empty', 'Damage+1']
# Jono loses with ['Warhammer', 'Leather', 'Empty', 'Damage+1']
# Jono loses with ['Dagger', 'Chainmail', 'Empty', 'Damage+1']
# Jono loses with ['Dagger', 'Chainmail', 'Empty', 'Damage+1']
# Jono loses with ['Warhammer', 'Empty', 'Empty', 'Defense+2']
# Jono loses with ['Warhammer', 'Empty', 'Empty', 'Defense+2']
# Jono loses with ['Longsword', 'Empty', 'Empty', 'Damage+1']
# Jono loses with ['Longsword', 'Empty', 'Empty', 'Damage+1']
# Jono loses with ['Dagger', 'Leather', 'Damage+1', 'Defense+1']
# Jono loses with ['Shortsword', 'Chainmail', 'Empty', 'Damage+1']
# Jono loses with ['Shortsword', 'Chainmail', 'Empty', 'Damage+1']
# Jono loses with ['Dagger', 'Empty', 'Defense+1', 'Defense+2']
# Jono loses with ['Shortsword', 'Leather', 'Damage+1', 'Defense+1']
# Jono loses with ['Shortsword', 'Empty', 'Defense+1', 'Defense+2']
# Jono loses with ['Warhammer', 'Empty', 'Damage+1', 'Defense+1']
# Jono loses with ['Dagger', 'Leather', 'Empty', 'Damage+2']
# Jono loses with ['Dagger', 'Leather', 'Empty', 'Damage+2']
# Jono loses with ['Longsword', 'Chainmail', 'Empty', 'Empty']
# Jono loses with ['Dagger', 'Empty', 'Damage+1', 'Defense+2']
# Jono loses with ['Shortsword', 'Leather', 'Empty', 'Damage+2']
# Jono loses with ['Shortsword', 'Leather', 'Empty', 'Damage+2']
# Jono loses with ['Longsword', 'Leather', 'Empty', 'Defense+1']
# Jono loses with ['Longsword', 'Leather', 'Empty', 'Defense+1']
# Jono loses with ['Greataxe', 'Empty', 'Empty', 'Empty']
# Jono loses with ['Shortsword', 'Empty', 'Damage+1', 'Defense+2']
# Jono loses with ['Warhammer', 'Empty', 'Empty', 'Damage+2']
# Jono loses with ['Warhammer', 'Empty', 'Empty', 'Damage+2']
# Jono loses with ['Warhammer', 'Chainmail', 'Empty', 'Defense+1']
# Jono loses with ['Warhammer', 'Chainmail', 'Empty', 'Defense+1']
# Jono loses with ['Dagger', 'Empty', 'Damage+2', 'Defense+1']
# Jono loses with ['Warhammer', 'Leather', 'Empty', 'Defense+2']
# Jono loses with ['Warhammer', 'Leather', 'Empty', 'Defense+2']
# Jono loses with ['Warhammer', 'Splintmail', 'Empty', 'Empty']
# Jono loses with ['Longsword', 'Leather', 'Empty', 'Damage+1']
# Jono loses with ['Longsword', 'Leather', 'Empty', 'Damage+1']
# Jono loses with ['Dagger', 'Chainmail', 'Empty', 'Defense+2']
# Jono loses with ['Dagger', 'Chainmail', 'Empty', 'Defense+2']
# Jono loses with ['Shortsword', 'Empty', 'Damage+2', 'Defense+1']
# Jono loses with ['Longsword', 'Empty', 'Empty', 'Defense+2']
# Jono loses with ['Longsword', 'Empty', 'Empty', 'Defense+2']
# Jono loses with ['Dagger', 'Leather', 'Defense+1', 'Defense+2']
# Jono loses with ['Dagger', 'Splintmail', 'Empty', 'Defense+1']
# Jono loses with ['Dagger', 'Splintmail', 'Empty', 'Defense+1']
# Jono loses with ['Shortsword', 'Chainmail', 'Empty', 'Defense+2']
# Jono loses with ['Shortsword', 'Chainmail', 'Empty', 'Defense+2']
# Jono loses with ['Warhammer', 'Chainmail', 'Empty', 'Damage+1']
# Jono loses with ['Warhammer', 'Chainmail', 'Empty', 'Damage+1']
# Jono loses with ['Dagger', 'Empty', 'Damage+1', 'Damage+2']
# Jono loses with ['Dagger', 'Bandedmail', 'Empty', 'Empty']
# Jono loses with ['Shortsword', 'Leather', 'Defense+1', 'Defense+2']
# Jono loses with ['Shortsword', 'Splintmail', 'Empty', 'Defense+1']
# Jono loses with ['Shortsword', 'Splintmail', 'Empty', 'Defense+1']
# Jono loses with ['Warhammer', 'Leather', 'Damage+1', 'Defense+1']
# Jono loses with ['Dagger', 'Chainmail', 'Damage+1', 'Defense+1']
# Jono loses with ['Shortsword', 'Empty', 'Damage+1', 'Damage+2']
# Jono loses with ['Shortsword', 'Bandedmail', 'Empty', 'Empty']
# Jono loses with ['Warhammer', 'Empty', 'Defense+1', 'Defense+2']
# Jono loses with ['Longsword', 'Empty', 'Damage+1', 'Defense+1']
# Jono loses with ['Dagger', 'Leather', 'Damage+1', 'Defense+2']
# Jono loses with ['Dagger', 'Splintmail', 'Empty', 'Damage+1']
# Jono loses with ['Dagger', 'Splintmail', 'Empty', 'Damage+1']
# Jono loses with ['Shortsword', 'Chainmail', 'Damage+1', 'Defense+1']
# Jono loses with ['Greataxe', 'Leather', 'Empty', 'Empty']
# Jono loses with ['Dagger', 'Empty', 'Empty', 'Defense+3']
# Jono loses with ['Dagger', 'Empty', 'Empty', 'Defense+3']
# Jono loses with ['Shortsword', 'Leather', 'Damage+1', 'Defense+2']
# Jono loses with ['Shortsword', 'Splintmail', 'Empty', 'Damage+1']
# Jono loses with ['Shortsword', 'Splintmail', 'Empty', 'Damage+1']
# Jono loses with ['Warhammer', 'Leather', 'Empty', 'Damage+2']
# Jono loses with ['Warhammer', 'Leather', 'Empty', 'Damage+2']
# Jono loses with ['Dagger', 'Chainmail', 'Empty', 'Damage+2']
# Jono loses with ['Dagger', 'Chainmail', 'Empty', 'Damage+2']
# Jono loses with ['Shortsword', 'Empty', 'Empty', 'Defense+3']
# Jono loses with ['Shortsword', 'Empty', 'Empty', 'Defense+3']
# Jono loses with ['Warhammer', 'Empty', 'Damage+1', 'Defense+2']
# Jono loses with ['Longsword', 'Empty', 'Empty', 'Damage+2']
# Jono loses with ['Longsword', 'Empty', 'Empty', 'Damage+2']
# Jono loses with ['Dagger', 'Leather', 'Damage+2', 'Defense+1']
# Jono loses with ['Shortsword', 'Chainmail', 'Empty', 'Damage+2']
# Jono loses with ['Shortsword', 'Chainmail', 'Empty', 'Damage+2']
# Jono wins for  91 with ['Longsword', 'Chainmail', 'Empty', 'Defense+1']

# %% [markdown]
# # --- Part Two ---
#
# Turns out the shopkeeper is working with the boss, and can persuade you to buy whatever items he wants. The other rules still apply, and he still only has one of each item.
#
# What is the most amount of gold you can spend and still lose the fight?

# %%
# As for Part 1, except list the inventories in order of costliest to cheapest
inventories = []
for x in list(itertools.product(*shop)):
    totalCost = 0
    totalCost = weapons['Cost'][x[0]] + armors['Cost'][x[1]] + pairs['Cost'][x[2]]
    inventories += [[totalCost, x[0], x[1], x[2]]]
inventories.sort(key = lambda x: x[0], reverse = True)
print(inventories)
# Out:
# [[356, 4, 5, 27], [329, 4, 4, 27], [326, 4, 5, 26], [322, 3, 5, 27], [316, 4, 5, 25], [307, 2, 5, 27], [307, 4, 3, 27], [306, 4, 5, 24], [301, 4, 5, 23], [299, 4, 4, 26], [296, 4, 5, 21], [296, 4, 5, 22], [295, 3, 4, 27], [292, 1, 5, 27], [292, 3, 5, 26], [290, 0, 5, 27], [289, 4, 4, 25], [285, 4, 2, 27], [282, 3, 5, 25], [281, 4, 5, 20], [280, 2, 4, 27], [279, 4, 4, 24], [277, 2, 5, 26], [277, 4, 3, 26], [276, 4, 5, 17], [276, 4, 5, 18], [276, 4, 5, 19], [274, 4, 4, 23], [273, 3, 3, 27], [272, 3, 5, 24], [269, 4, 4, 21], [269, 4, 4, 22], [267, 2, 5, 25], [267, 3, 5, 23], [267, 4, 1, 27], [267, 4, 3, 25], [266, 4, 5, 16], [265, 1, 4, 27], [265, 3, 4, 26], [263, 0, 4, 27], [262, 1, 5, 26], [262, 3, 5, 21], [262, 3, 5, 22], [260, 0, 5, 26], [258, 2, 3, 27], [257, 2, 5, 24], [257, 4, 3, 24], [256, 4, 5, 14], [256, 4, 5, 15], [255, 3, 4, 25], [255, 4, 2, 26], [254, 4, 0, 27], [254, 4, 4, 20], [252, 1, 5, 25], [252, 2, 5, 23], [252, 4, 3, 23], [251, 3, 2, 27], [251, 4, 5, 13], [250, 0, 5, 25], [250, 2, 4, 26], [249, 4, 4, 17], [249, 4, 4, 18], [249, 4, 4, 19], [247, 2, 5, 21], [247, 2, 5, 22], [247, 3, 5, 20], [247, 4, 3, 21], [247, 4, 3, 22], [246, 4, 5, 12], [245, 3, 4, 24], [245, 4, 2, 25], [243, 1, 3, 27], [243, 3, 3, 26], [242, 1, 5, 24], [242, 3, 5, 17], [242, 3, 5, 18], [242, 3, 5, 19], [241, 0, 3, 27], [241, 4, 5, 11], [240, 0, 5, 24], [240, 2, 4, 25], [240, 3, 4, 23], [239, 4, 4, 16], [237, 1, 5, 23], [237, 4, 1, 26], [236, 2, 2, 27], [236, 4, 5, 10], [235, 0, 5, 23], [235, 1, 4, 26], [235, 3, 4, 21], [235, 3, 4, 22], [235, 4, 2, 24], [233, 0, 4, 26], [233, 3, 1, 27], [233, 3, 3, 25], [232, 1, 5, 21], [232, 1, 5, 22], [232, 2, 5, 20], [232, 3, 5, 16], [232, 4, 3, 20], [230, 0, 5, 21], [230, 0, 5, 22], [230, 2, 4, 24], [230, 4, 2, 23], [229, 4, 4, 14], [229, 4, 4, 15], [228, 2, 3, 26], [227, 2, 5, 17], [227, 2, 5, 18], [227, 2, 5, 19], [227, 4, 1, 25], [227, 4, 3, 17], [227, 4, 3, 18], [227, 4, 3, 19], [226, 4, 5, 8], [226, 4, 5, 9], [225, 1, 4, 25], [225, 2, 4, 23], [225, 4, 2, 21], [225, 4, 2, 22], [224, 4, 0, 26], [224, 4, 4, 13], [223, 0, 4, 25], [223, 3, 3, 24], [222, 3, 5, 14], [222, 3, 5, 15], [221, 1, 2, 27], [221, 3, 2, 26], [221, 4, 5, 7], [220, 2, 4, 21], [220, 2, 4, 22], [220, 3, 0, 27], [220, 3, 4, 20], [219, 0, 2, 27], [219, 4, 4, 12], [218, 2, 1, 27], [218, 2, 3, 25], [218, 3, 3, 23], [217, 1, 5, 20], [217, 2, 5, 16], [217, 3, 5, 13], [217, 4, 1, 24], [217, 4, 3, 16], [216, 4, 5, 5], [216, 4, 5, 6], [215, 0, 5, 20], [215, 1, 4, 24], [215, 3, 4, 17], [215, 3, 4, 18], [215, 3, 4, 19], [214, 4, 0, 25], [214, 4, 4, 11], [213, 0, 4, 24], [213, 1, 3, 26], [213, 3, 3, 21], [213, 3, 3, 22], [212, 1, 5, 17], [212, 1, 5, 18], [212, 1, 5, 19], [212, 3, 5, 12], [212, 4, 1, 23], [211, 0, 3, 26], [211, 3, 2, 25], [210, 0, 5, 17], [210, 0, 5, 18], [210, 0, 5, 19], [210, 1, 4, 23], [210, 4, 2, 20], [209, 4, 4, 10], [208, 0, 4, 23], [208, 2, 3, 24], [207, 2, 5, 14], [207, 2, 5, 15], [207, 3, 5, 11], [207, 4, 1, 21], [207, 4, 1, 22], [207, 4, 3, 14], [207, 4, 3, 15], [206, 2, 2, 26], [205, 1, 4, 21], [205, 1, 4, 22], [205, 2, 0, 27], [205, 2, 4, 20], [205, 3, 4, 16], [205, 4, 2, 17], [205, 4, 2, 18], [205, 4, 2, 19], [204, 4, 0, 24], [203, 0, 4, 21], [203, 0, 4, 22], [203, 1, 1, 27], [203, 1, 3, 25], [203, 2, 3, 23], [203, 3, 1, 26], [202, 1, 5, 16], [202, 2, 5, 13], [202, 3, 5, 10], [202, 4, 3, 13], [201, 0, 1, 27], [201, 0, 3, 25], [201, 3, 2, 24], [201, 4, 5, 3], [201, 4, 5, 4], [200, 0, 5, 16], [200, 2, 4, 17], [200, 2, 4, 18], [200, 2, 4, 19], [199, 4, 0, 23], [199, 4, 4, 8], [199, 4, 4, 9], [198, 2, 3, 21], [198, 2, 3, 22], [198, 3, 3, 20], [197, 2, 5, 12], [197, 4, 3, 12], [196, 2, 2, 25], [196, 3, 2, 23], [196, 4, 5, 1], [196, 4, 5, 2], [195, 3, 4, 14], [195, 3, 4, 15], [195, 4, 2, 16], [194, 4, 0, 21], [194, 4, 0, 22], [194, 4, 4, 7], [193, 1, 3, 24], [193, 3, 1, 25], [193, 3, 3, 17], [193, 3, 3, 18], [193, 3, 3, 19], [192, 1, 5, 14], [192, 1, 5, 15], [192, 2, 5, 11], [192, 3, 5, 8], [192, 3, 5, 9], [192, 4, 1, 20], [ ...

# %%
# As for Part 1, except stop when you lose the simulation
win = False
loss = False
for inventory in inventories:
    if loss == True:
        break
    else:
        Jono['HP'] = 100
        Boss['HP'] = 100
        win = False
    Jono['Damage'] = weapons['Damage'][inventory[1]] + pairs['Damage'][inventory[3]]
    Jono['Defense'] = armors['Defense'][inventory[2]] + pairs['Defense'][inventory[3]]
    while win == False and loss == False:
        if Jono['Damage'] - Boss['Defense'] >= 1:
            Boss['HP'] -= Jono['Damage'] - Boss['Defense']
        else:
            Boss['HP'] -= 1
        if Boss['HP'] <= 0:
            win = True
            winningSet = [weapons['Name'][inventory[1]], armors['Name'][inventory[2]], rings['Name'][pairs['Ring 1'][inventory[3]]], rings['Name'][pairs['Ring 2'][inventory[3]]]]
            print('Jono wins with', winningSet)
        elif Boss['Damage'] - Jono['Defense'] >= 1:
            Jono['HP'] -= Boss['Damage'] - Jono['Defense']
        else:
            Jono['HP'] -= 1
        if Jono['HP'] <= 0:
            loss = True
            losingSet = [weapons['Name'][inventory[1]], armors['Name'][inventory[2]], rings['Name'][pairs['Ring 1'][inventory[3]]], rings['Name'][pairs['Ring 2'][inventory[3]]]]
            print('Jono loses for', inventory[0], 'with', losingSet)
# Out:
# Jono wins with ['Greataxe', 'Platemail', 'Damage+3', 'Defense+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Greataxe', 'Platemail', 'Damage+2', 'Damage+3']
# Jono wins with ['Longsword', 'Platemail', 'Damage+3', 'Defense+3']
# Jono wins with ['Greataxe', 'Platemail', 'Damage+3', 'Defense+2']
# Jono wins with ['Warhammer', 'Platemail', 'Damage+3', 'Defense+3']
# Jono wins with ['Greataxe', 'Splintmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Greataxe', 'Platemail', 'Damage+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Platemail', 'Damage+1', 'Damage+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Greataxe', 'Platemail', 'Damage+3', 'Defense+1']
# Jono wins with ['Greataxe', 'Platemail', 'Defense+2', 'Defense+3']
# Jono wins with ['Longsword', 'Bandedmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Shortsword', 'Platemail', 'Damage+3', 'Defense+3']
# Jono wins with ['Longsword', 'Platemail', 'Damage+2', 'Damage+3']
# Jono wins with ['Dagger', 'Platemail', 'Damage+3', 'Defense+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Greataxe', 'Chainmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Longsword', 'Platemail', 'Damage+3', 'Defense+2']
# Jono wins with ['Greataxe', 'Platemail', 'Damage+1', 'Defense+3']
# Jono wins with ['Warhammer', 'Bandedmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Warhammer', 'Platemail', 'Damage+2', 'Damage+3']
# Jono wins with ['Greataxe', 'Splintmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Greataxe', 'Platemail', 'Empty', 'Damage+3']
# Jono wins with ['Greataxe', 'Platemail', 'Empty', 'Damage+3']
# Jono wins with ['Greataxe', 'Platemail', 'Defense+1', 'Defense+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Longsword', 'Splintmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Longsword', 'Platemail', 'Damage+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Greataxe', 'Bandedmail', 'Defense+2', 'Defense+3']
# Jono wins with ['Warhammer', 'Platemail', 'Damage+3', 'Defense+2']
# Jono wins with ['Longsword', 'Platemail', 'Damage+1', 'Damage+3']
# Jono wins with ['Greataxe', 'Leather', 'Damage+3', 'Defense+3']
# Jono wins with ['Greataxe', 'Splintmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Greataxe', 'Platemail', 'Damage+2', 'Defense+2']
# Jono wins with ['Shortsword', 'Bandedmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Longsword', 'Bandedmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Dagger', 'Bandedmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Shortsword', 'Platemail', 'Damage+2', 'Damage+3']
# Jono wins with ['Longsword', 'Platemail', 'Damage+3', 'Defense+1']
# Jono wins with ['Longsword', 'Platemail', 'Defense+2', 'Defense+3']
# Jono wins with ['Dagger', 'Platemail', 'Damage+2', 'Damage+3']
# Jono wins with ['Warhammer', 'Splintmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Warhammer', 'Platemail', 'Damage+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Splintmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Platemail', 'Empty', 'Defense+3']
# Jono wins with ['Greataxe', 'Platemail', 'Empty', 'Defense+3']
# Jono wins with ['Longsword', 'Bandedmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Greataxe', 'Chainmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Greataxe', 'Empty', 'Damage+3', 'Defense+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Damage+1', 'Defense+3']
# Jono wins with ['Shortsword', 'Platemail', 'Damage+3', 'Defense+2']
# Jono wins with ['Warhammer', 'Platemail', 'Damage+1', 'Damage+3']
# Jono wins with ['Greataxe', 'Splintmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Longsword', 'Chainmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Greataxe', 'Platemail', 'Damage+1', 'Damage+2']
# Jono wins with ['Dagger', 'Platemail', 'Damage+3', 'Defense+2']
# Jono wins with ['Warhammer', 'Bandedmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Empty', 'Damage+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Empty', 'Damage+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Defense+1', 'Defense+3']
# Jono wins with ['Warhammer', 'Platemail', 'Damage+3', 'Defense+1']
# Jono wins with ['Warhammer', 'Platemail', 'Defense+2', 'Defense+3']
# Jono wins with ['Longsword', 'Platemail', 'Damage+1', 'Defense+3']
# Jono wins with ['Greataxe', 'Splintmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Greataxe', 'Splintmail', 'Defense+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Platemail', 'Damage+2', 'Defense+1']
# Jono wins with ['Longsword', 'Bandedmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Chainmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Shortsword', 'Splintmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Longsword', 'Splintmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Shortsword', 'Platemail', 'Damage+2', 'Defense+3']
# Jono wins with ['Longsword', 'Platemail', 'Empty', 'Damage+3']
# Jono wins with ['Longsword', 'Platemail', 'Empty', 'Damage+3']
# Jono wins with ['Longsword', 'Platemail', 'Defense+1', 'Defense+3']
# Jono wins with ['Dagger', 'Splintmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Greataxe', 'Platemail', 'Damage+1', 'Defense+2']
# Jono wins with ['Dagger', 'Platemail', 'Damage+2', 'Defense+3']
# Jono wins with ['Warhammer', 'Bandedmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Longsword', 'Bandedmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Damage+2', 'Defense+2']
# Jono wins with ['Shortsword', 'Platemail', 'Damage+1', 'Damage+3']
# Jono wins with ['Greataxe', 'Leather', 'Damage+2', 'Damage+3']
# Jono wins with ['Warhammer', 'Chainmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Greataxe', 'Platemail', 'Defense+1', 'Defense+2']
# Jono wins with ['Dagger', 'Platemail', 'Damage+1', 'Damage+3']
# Jono wins with ['Shortsword', 'Bandedmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Longsword', 'Bandedmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Longsword', 'Bandedmail', 'Defense+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Chainmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Dagger', 'Bandedmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Longsword', 'Leather', 'Damage+3', 'Defense+3']
# Jono wins with ['Longsword', 'Splintmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Shortsword', 'Platemail', 'Damage+3', 'Defense+1']
# Jono wins with ['Shortsword', 'Platemail', 'Defense+2', 'Defense+3']
# Jono wins with ['Warhammer', 'Platemail', 'Damage+1', 'Defense+3']
# Jono wins with ['Longsword', 'Platemail', 'Damage+2', 'Defense+2']
# Jono wins with ['Greataxe', 'Splintmail', 'Damage+1', 'Defense+3']
# Jono wins with ['Dagger', 'Platemail', 'Damage+3', 'Defense+1']
# Jono wins with ['Dagger', 'Platemail', 'Defense+2', 'Defense+3']
# Jono wins with ['Warhammer', 'Bandedmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Chainmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Empty', 'Defense+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Empty', 'Defense+3']
# Jono wins with ['Warhammer', 'Splintmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Warhammer', 'Platemail', 'Empty', 'Damage+3']
# Jono wins with ['Warhammer', 'Platemail', 'Empty', 'Damage+3']
# Jono wins with ['Warhammer', 'Platemail', 'Defense+1', 'Defense+3']
# Jono wins with ['Greataxe', 'Leather', 'Damage+3', 'Defense+2']
# Jono wins with ['Greataxe', 'Splintmail', 'Empty', 'Damage+3']
# Jono wins with ['Greataxe', 'Splintmail', 'Empty', 'Damage+3']
# Jono wins with ['Greataxe', 'Splintmail', 'Defense+1', 'Defense+3']
# Jono wins with ['Greataxe', 'Platemail', 'Empty', 'Damage+2']
# Jono wins with ['Greataxe', 'Platemail', 'Empty', 'Damage+2']
# Jono wins with ['Shortsword', 'Bandedmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Warhammer', 'Bandedmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Greataxe', 'Chainmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Greataxe', 'Chainmail', 'Defense+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Empty', 'Damage+2', 'Damage+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Damage+1', 'Damage+2']
# Jono wins with ['Dagger', 'Bandedmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Longsword', 'Splintmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Longsword', 'Platemail', 'Empty', 'Defense+3']
# Jono wins with ['Longsword', 'Platemail', 'Empty', 'Defense+3']
# Jono wins with ['Shortsword', 'Chainmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Longsword', 'Chainmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Greataxe', 'Platemail', 'Damage+1', 'Defense+1']
# Jono wins with ['Warhammer', 'Bandedmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Warhammer', 'Bandedmail', 'Defense+2', 'Defense+3']
# Jono wins with ['Longsword', 'Empty', 'Damage+3', 'Defense+3']
# Jono wins with ['Longsword', 'Bandedmail', 'Damage+1', 'Defense+3']
# Jono wins with ['Dagger', 'Chainmail', 'Damage+3', 'Defense+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Damage+2', 'Defense+1']
# Jono wins with ['Warhammer', 'Leather', 'Damage+3', 'Defense+3']
# Jono wins with ['Warhammer', 'Splintmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Longsword', 'Splintmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Shortsword', 'Platemail', 'Damage+1', 'Defense+3']
# Jono wins with ['Warhammer', 'Platemail', 'Damage+2', 'Defense+2']
# Jono wins with ['Longsword', 'Platemail', 'Damage+1', 'Damage+2']
# Jono wins with ['Greataxe', 'Leather', 'Damage+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Splintmail', 'Damage+2', 'Defense+2']
# Jono wins with ['Greataxe', 'Platemail', 'Empty', 'Defense+2']
# Jono wins with ['Greataxe', 'Platemail', 'Empty', 'Defense+2']
# Jono wins with ['Dagger', 'Platemail', 'Damage+1', 'Defense+3']
# Jono wins with ['Shortsword', 'Bandedmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Longsword', 'Bandedmail', 'Empty', 'Damage+3']
# Jono wins with ['Longsword', 'Bandedmail', 'Empty', 'Damage+3']
# Jono wins with ['Longsword', 'Bandedmail', 'Defense+1', 'Defense+3']
# Jono wins with ['Greataxe', 'Empty', 'Damage+3', 'Defense+2']
# Jono wins with ['Greataxe', 'Bandedmail', 'Damage+1', 'Defense+2']
# Jono wins with ['Dagger', 'Bandedmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Shortsword', 'Splintmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Longsword', 'Splintmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Longsword', 'Splintmail', 'Defense+2', 'Defense+3']
# Jono wins with ['Shortsword', 'Platemail', 'Empty', 'Damage+3']
# Jono wins with ['Shortsword', 'Platemail', 'Empty', 'Damage+3']
# Jono wins with ['Shortsword', 'Platemail', 'Defense+1', 'Defense+3']
# Jono wins with ['Longsword', 'Platemail', 'Damage+2', 'Defense+1']
# Jono wins with ['Greataxe', 'Leather', 'Damage+1', 'Damage+3']
# Jono wins with ['Dagger', 'Splintmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Longsword', 'Chainmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Dagger', 'Platemail', 'Empty', 'Damage+3']
# Jono wins with ['Dagger', 'Platemail', 'Empty', 'Damage+3']
# Jono wins with ['Dagger', 'Platemail', 'Defense+1', 'Defense+3']
# Jono wins with ['Shortsword', 'Bandedmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Greataxe', 'Chainmail', 'Damage+1', 'Defense+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Defense+1', 'Defense+2']
# Jono wins with ['Dagger', 'Bandedmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Warhammer', 'Splintmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Warhammer', 'Platemail', 'Empty', 'Defense+3']
# Jono wins with ['Warhammer', 'Platemail', 'Empty', 'Defense+3']
# Jono wins with ['Longsword', 'Platemail', 'Damage+1', 'Defense+2']
# Jono wins with ['Greataxe', 'Leather', 'Damage+3', 'Defense+1']
# Jono wins with ['Greataxe', 'Leather', 'Defense+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Splintmail', 'Empty', 'Defense+3']
# Jono wins with ['Greataxe', 'Splintmail', 'Empty', 'Defense+3']
# Jono wins with ['Warhammer', 'Chainmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Shortsword', 'Bandedmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Shortsword', 'Bandedmail', 'Defense+2', 'Defense+3']
# Jono wins with ['Warhammer', 'Empty', 'Damage+3', 'Defense+3']
# Jono wins with ['Warhammer', 'Bandedmail', 'Damage+1', 'Defense+3']
# Jono wins with ['Longsword', 'Bandedmail', 'Damage+2', 'Defense+2']
# Jono wins with ['Greataxe', 'Chainmail', 'Empty', 'Damage+3']
# Jono wins with ['Greataxe', 'Chainmail', 'Empty', 'Damage+3']
# Jono wins with ['Greataxe', 'Chainmail', 'Defense+1', 'Defense+3']
# Jono wins with ['Greataxe', 'Empty', 'Damage+2', 'Defense+3']
# Jono wins with ['Dagger', 'Bandedmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Dagger', 'Bandedmail', 'Defense+2', 'Defense+3']
# Jono wins with ['Shortsword', 'Leather', 'Damage+3', 'Defense+3']
# Jono wins with ['Shortsword', 'Splintmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Warhammer', 'Splintmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Longsword', 'Leather', 'Damage+2', 'Damage+3']
# Jono wins with ['Shortsword', 'Platemail', 'Damage+2', 'Defense+2']
# Jono wins with ['Warhammer', 'Platemail', 'Damage+1', 'Damage+2']
# Jono wins with ['Longsword', 'Platemail', 'Defense+1', 'Defense+2']
# Jono wins with ['Greataxe', 'Splintmail', 'Damage+1', 'Damage+2']
# Jono wins with ['Dagger', 'Leather', 'Damage+3', 'Defense+3']
# Jono wins with ['Dagger', 'Splintmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Longsword', 'Chainmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Platemail', 'Empty', 'Damage+1']
# Jono wins with ['Greataxe', 'Platemail', 'Empty', 'Damage+1']
# Jono wins with ['Dagger', 'Platemail', 'Damage+2', 'Defense+2']
# Jono wins with ['Warhammer', 'Bandedmail', 'Empty', 'Damage+3']
# Jono wins with ['Warhammer', 'Bandedmail', 'Empty', 'Damage+3']
# Jono wins with ['Warhammer', 'Bandedmail', 'Defense+1', 'Defense+3']
# Jono wins with ['Greataxe', 'Empty', 'Damage+1', 'Damage+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Empty', 'Damage+2']
# Jono wins with ['Greataxe', 'Bandedmail', 'Empty', 'Damage+2']
# Jono wins with ['Warhammer', 'Splintmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Warhammer', 'Splintmail', 'Defense+2', 'Defense+3']
# Jono wins with ['Longsword', 'Splintmail', 'Damage+1', 'Defense+3']
# Jono wins with ['Warhammer', 'Platemail', 'Damage+2', 'Defense+1']
# Jono wins with ['Greataxe', 'Splintmail', 'Damage+2', 'Defense+1']
# Jono wins with ['Warhammer', 'Chainmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Longsword', 'Chainmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Greataxe', 'Platemail', 'Empty', 'Defense+1']
# Jono wins with ['Greataxe', 'Platemail', 'Empty', 'Defense+1']
# Jono wins with ['Longsword', 'Bandedmail', 'Empty', 'Defense+3']
# Jono wins with ['Longsword', 'Bandedmail', 'Empty', 'Defense+3']
# Jono wins with ['Greataxe', 'Chainmail', 'Damage+2', 'Defense+2']
# Jono wins with ['Greataxe', 'Empty', 'Damage+3', 'Defense+1']
# Jono wins with ['Greataxe', 'Empty', 'Defense+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Damage+1', 'Defense+1']
# Jono wins with ['Shortsword', 'Splintmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Longsword', 'Leather', 'Damage+3', 'Defense+2']
# Jono wins with ['Longsword', 'Splintmail', 'Empty', 'Damage+3']
# Jono wins with ['Longsword', 'Splintmail', 'Empty', 'Damage+3']
# Jono wins with ['Longsword', 'Splintmail', 'Defense+1', 'Defense+3']
# Jono wins with ['Shortsword', 'Platemail', 'Empty', 'Defense+3']
# Jono wins with ['Shortsword', 'Platemail', 'Empty', 'Defense+3']
# Jono wins with ['Warhammer', 'Platemail', 'Damage+1', 'Defense+2']
# Jono wins with ['Longsword', 'Platemail', 'Empty', 'Damage+2']
# Jono wins with ['Longsword', 'Platemail', 'Empty', 'Damage+2']
# Jono wins with ['Greataxe', 'Leather', 'Damage+1', 'Defense+3']
# Jono wins with ['Greataxe', 'Splintmail', 'Damage+1', 'Defense+2']
# Jono wins with ['Dagger', 'Splintmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Shortsword', 'Chainmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Longsword', 'Chainmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Longsword', 'Chainmail', 'Defense+2', 'Defense+3']
# Jono wins with ['Dagger', 'Platemail', 'Empty', 'Defense+3']
# Jono wins with ['Dagger', 'Platemail', 'Empty', 'Defense+3']
# Jono wins with ['Shortsword', 'Empty', 'Damage+3', 'Defense+3']
# Jono wins with ['Shortsword', 'Bandedmail', 'Damage+1', 'Defense+3']
# Jono wins with ['Warhammer', 'Bandedmail', 'Damage+2', 'Defense+2']
# Jono wins with ['Longsword', 'Empty', 'Damage+2', 'Damage+3']
# Jono wins with ['Longsword', 'Bandedmail', 'Damage+1', 'Damage+2']
# Jono wins with ['Dagger', 'Chainmail', 'Damage+2', 'Damage+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Empty', 'Defense+2']
# Jono wins with ['Greataxe', 'Bandedmail', 'Empty', 'Defense+2']
# Jono wins with ['Dagger', 'Empty', 'Damage+3', 'Defense+3']
# Jono wins with ['Dagger', 'Bandedmail', 'Damage+1', 'Defense+3']
# Jono wins with ['Shortsword', 'Splintmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Warhammer', 'Leather', 'Damage+2', 'Damage+3']
# Jono wins with ['Shortsword', 'Platemail', 'Damage+1', 'Damage+2']
# Jono wins with ['Warhammer', 'Platemail', 'Defense+1', 'Defense+2']
# Jono wins with ['Longsword', 'Platemail', 'Damage+1', 'Defense+1']
# Jono wins with ['Greataxe', 'Leather', 'Empty', 'Damage+3']
# Jono wins with ['Greataxe', 'Leather', 'Empty', 'Damage+3']
# Jono wins with ['Greataxe', 'Leather', 'Defense+1', 'Defense+3']
# Jono wins with ['Greataxe', 'Splintmail', 'Defense+1', 'Defense+2']
# Jono wins with ['Dagger', 'Splintmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Warhammer', 'Chainmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Dagger', 'Platemail', 'Damage+1', 'Damage+2']
# Jono wins with ['Shortsword', 'Bandedmail', 'Empty', 'Damage+3']
# Jono wins with ['Shortsword', 'Bandedmail', 'Empty', 'Damage+3']
# Jono wins with ['Shortsword', 'Bandedmail', 'Defense+1', 'Defense+3']
# Jono wins with ['Longsword', 'Bandedmail', 'Damage+2', 'Defense+1']
# Jono wins with ['Greataxe', 'Chainmail', 'Empty', 'Defense+3']
# Jono wins with ['Greataxe', 'Chainmail', 'Empty', 'Defense+3']
# Jono wins with ['Dagger', 'Bandedmail', 'Empty', 'Damage+3']
# Jono wins with ['Dagger', 'Bandedmail', 'Empty', 'Damage+3']
# Jono wins with ['Dagger', 'Bandedmail', 'Defense+1', 'Defense+3']
# Jono wins with ['Shortsword', 'Splintmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Shortsword', 'Splintmail', 'Defense+2', 'Defense+3']
# Jono wins with ['Warhammer', 'Splintmail', 'Damage+1', 'Defense+3']
# Jono wins with ['Longsword', 'Leather', 'Damage+2', 'Defense+3']
# Jono wins with ['Longsword', 'Splintmail', 'Damage+2', 'Defense+2']
# Jono wins with ['Shortsword', 'Platemail', 'Damage+2', 'Defense+1']
# Jono wins with ['Longsword', 'Platemail', 'Empty', 'Defense+2']
# Jono wins with ['Longsword', 'Platemail', 'Empty', 'Defense+2']
# Jono wins with ['Dagger', 'Splintmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Dagger', 'Splintmail', 'Defense+2', 'Defense+3']
# Jono wins with ['Shortsword', 'Chainmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Warhammer', 'Chainmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Dagger', 'Platemail', 'Damage+2', 'Defense+1']
# Jono wins with ['Warhammer', 'Bandedmail', 'Empty', 'Defense+3']
# Jono wins with ['Warhammer', 'Bandedmail', 'Empty', 'Defense+3']
# Jono wins with ['Longsword', 'Empty', 'Damage+3', 'Defense+2']
# Jono wins with ['Longsword', 'Bandedmail', 'Damage+1', 'Defense+2']
# Jono wins with ['Greataxe', 'Chainmail', 'Damage+1', 'Damage+2']
# Jono wins with ['Dagger', 'Chainmail', 'Damage+3', 'Defense+2']
# Jono wins with ['Greataxe', 'Empty', 'Damage+1', 'Defense+3']
# Jono wins with ['Warhammer', 'Leather', 'Damage+3', 'Defense+2']
# Jono wins with ['Warhammer', 'Splintmail', 'Empty', 'Damage+3']
# Jono wins with ['Warhammer', 'Splintmail', 'Empty', 'Damage+3']
# Jono wins with ['Warhammer', 'Splintmail', 'Defense+1', 'Defense+3']
# Jono wins with ['Longsword', 'Leather', 'Damage+1', 'Damage+3']
# Jono wins with ['Shortsword', 'Platemail', 'Damage+1', 'Defense+2']
# Jono wins with ['Warhammer', 'Platemail', 'Empty', 'Damage+2']
# Jono wins with ['Warhammer', 'Platemail', 'Empty', 'Damage+2']
# Jono wins with ['Greataxe', 'Leather', 'Damage+2', 'Defense+2']
# Jono wins with ['Greataxe', 'Splintmail', 'Empty', 'Damage+2']
# Jono wins with ['Greataxe', 'Splintmail', 'Empty', 'Damage+2']
# Jono wins with ['Warhammer', 'Chainmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Warhammer', 'Chainmail', 'Defense+2', 'Defense+3']
# Jono wins with ['Longsword', 'Chainmail', 'Damage+1', 'Defense+3']
# Jono wins with ['Greataxe', 'Platemail', 'Empty', 'Empty']
# Jono wins with ['Dagger', 'Platemail', 'Damage+1', 'Defense+2']
# Jono wins with ['Shortsword', 'Bandedmail', 'Damage+2', 'Defense+2']
# Jono wins with ['Warhammer', 'Empty', 'Damage+2', 'Damage+3']
# Jono wins with ['Warhammer', 'Bandedmail', 'Damage+1', 'Damage+2']
# Jono wins with ['Longsword', 'Bandedmail', 'Defense+1', 'Defense+2']
# Jono wins with ['Greataxe', 'Chainmail', 'Damage+2', 'Defense+1']
# Jono wins with ['Greataxe', 'Empty', 'Empty', 'Damage+3']
# Jono wins with ['Greataxe', 'Empty', 'Empty', 'Damage+3']
# Jono wins with ['Greataxe', 'Empty', 'Defense+1', 'Defense+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Empty', 'Damage+1']
# Jono wins with ['Greataxe', 'Bandedmail', 'Empty', 'Damage+1']
# Jono wins with ['Dagger', 'Bandedmail', 'Damage+2', 'Defense+2']
# Jono wins with ['Shortsword', 'Leather', 'Damage+2', 'Damage+3']
# Jono wins with ['Longsword', 'Leather', 'Damage+3', 'Defense+1']
# Jono wins with ['Longsword', 'Leather', 'Defense+2', 'Defense+3']
# Jono wins with ['Longsword', 'Splintmail', 'Empty', 'Defense+3']
# Jono wins with ['Longsword', 'Splintmail', 'Empty', 'Defense+3']
# Jono wins with ['Shortsword', 'Platemail', 'Defense+1', 'Defense+2']
# Jono wins with ['Warhammer', 'Platemail', 'Damage+1', 'Defense+1']
# Jono wins with ['Greataxe', 'Splintmail', 'Damage+1', 'Defense+1']
# Jono wins with ['Dagger', 'Leather', 'Damage+2', 'Damage+3']
# Jono wins with ['Shortsword', 'Chainmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Longsword', 'Chainmail', 'Empty', 'Damage+3']
# Jono wins with ['Longsword', 'Chainmail', 'Empty', 'Damage+3']
# Jono wins with ['Longsword', 'Chainmail', 'Defense+1', 'Defense+3']
# Jono wins with ['Dagger', 'Platemail', 'Defense+1', 'Defense+2']
# Jono wins with ['Warhammer', 'Bandedmail', 'Damage+2', 'Defense+1']
# Jono wins with ['Longsword', 'Empty', 'Damage+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Chainmail', 'Damage+1', 'Defense+2']
# Jono wins with ['Dagger', 'Chainmail', 'Damage+2', 'Defense+3']
# Jono wins with ['Greataxe', 'Bandedmail', 'Empty', 'Defense+1']
# Jono wins with ['Greataxe', 'Bandedmail', 'Empty', 'Defense+1']
# Jono wins with ['Shortsword', 'Splintmail', 'Damage+1', 'Defense+3']
# Jono wins with ['Warhammer', 'Leather', 'Damage+2', 'Defense+3']
# Jono wins with ['Warhammer', 'Splintmail', 'Damage+2', 'Defense+2']
# Jono wins with ['Longsword', 'Splintmail', 'Damage+1', 'Damage+2']
# Jono wins with ['Warhammer', 'Platemail', 'Empty', 'Defense+2']
# Jono wins with ['Warhammer', 'Platemail', 'Empty', 'Defense+2']
# Jono wins with ['Longsword', 'Platemail', 'Empty', 'Damage+1']
# Jono wins with ['Longsword', 'Platemail', 'Empty', 'Damage+1']
# Jono wins with ['Greataxe', 'Leather', 'Empty', 'Defense+3']
# Jono wins with ['Greataxe', 'Leather', 'Empty', 'Defense+3']
# Jono wins with ['Greataxe', 'Splintmail', 'Empty', 'Defense+2']
# Jono wins with ['Greataxe', 'Splintmail', 'Empty', 'Defense+2']
# Jono wins with ['Dagger', 'Splintmail', 'Damage+1', 'Defense+3']
# Jono wins with ['Shortsword', 'Chainmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Shortsword', 'Bandedmail', 'Empty', 'Defense+3']
# Jono wins with ['Shortsword', 'Bandedmail', 'Empty', 'Defense+3']
# Jono wins with ['Warhammer', 'Empty', 'Damage+3', 'Defense+2']
# Jono wins with ['Warhammer', 'Bandedmail', 'Damage+1', 'Defense+2']
# Jono wins with ['Longsword', 'Empty', 'Damage+1', 'Damage+3']
# Jono wins with ['Longsword', 'Bandedmail', 'Empty', 'Damage+2']
# Jono wins with ['Longsword', 'Bandedmail', 'Empty', 'Damage+2']
# Jono wins with ['Greataxe', 'Chainmail', 'Defense+1', 'Defense+2']
# Jono wins with ['Dagger', 'Chainmail', 'Damage+1', 'Damage+3']
# Jono wins with ['Greataxe', 'Empty', 'Damage+2', 'Defense+2']
# Jono wins with ['Dagger', 'Bandedmail', 'Empty', 'Defense+3']
# Jono wins with ['Dagger', 'Bandedmail', 'Empty', 'Defense+3']
# Jono wins with ['Shortsword', 'Leather', 'Damage+3', 'Defense+2']
# Jono wins with ['Shortsword', 'Splintmail', 'Empty', 'Damage+3']
# Jono wins with ['Shortsword', 'Splintmail', 'Empty', 'Damage+3']
# Jono wins with ['Shortsword', 'Splintmail', 'Defense+1', 'Defense+3']
# Jono wins with ['Warhammer', 'Leather', 'Damage+1', 'Damage+3']
# Jono wins with ['Longsword', 'Splintmail', 'Damage+2', 'Defense+1']
# Jono wins with ['Shortsword', 'Platemail', 'Empty', 'Damage+2']
# Jono wins with ['Shortsword', 'Platemail', 'Empty', 'Damage+2']
# Jono wins with ['Longsword', 'Platemail', 'Empty', 'Defense+1']
# Jono wins with ['Longsword', 'Platemail', 'Empty', 'Defense+1']
# Jono wins with ['Greataxe', 'Leather', 'Damage+1', 'Damage+2']
# Jono wins with ['Dagger', 'Leather', 'Damage+3', 'Defense+2']
# Jono wins with ['Dagger', 'Splintmail', 'Empty', 'Damage+3']
# Jono wins with ['Dagger', 'Splintmail', 'Empty', 'Damage+3']
# Jono wins with ['Dagger', 'Splintmail', 'Defense+1', 'Defense+3']
# Jono wins with ['Shortsword', 'Chainmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Shortsword', 'Chainmail', 'Defense+2', 'Defense+3']
# Jono wins with ['Warhammer', 'Chainmail', 'Damage+1', 'Defense+3']
# Jono wins with ['Longsword', 'Chainmail', 'Damage+2', 'Defense+2']
# Jono wins with ['Dagger', 'Platemail', 'Empty', 'Damage+2']
# Jono wins with ['Dagger', 'Platemail', 'Empty', 'Damage+2']
# Jono wins with ['Shortsword', 'Empty', 'Damage+2', 'Damage+3']
# Jono wins with ['Shortsword', 'Bandedmail', 'Damage+1', 'Damage+2']
# Jono wins with ['Warhammer', 'Bandedmail', 'Defense+1', 'Defense+2']
# Jono wins with ['Longsword', 'Empty', 'Damage+3', 'Defense+1']
# Jono wins with ['Longsword', 'Empty', 'Defense+2', 'Defense+3']
# Jono wins with ['Longsword', 'Bandedmail', 'Damage+1', 'Defense+1']
# Jono wins with ['Dagger', 'Chainmail', 'Damage+3', 'Defense+1']
# Jono wins with ['Dagger', 'Chainmail', 'Defense+2', 'Defense+3']
# Jono loses for 158 with ['Dagger', 'Empty', 'Damage+2', 'Damage+3']
