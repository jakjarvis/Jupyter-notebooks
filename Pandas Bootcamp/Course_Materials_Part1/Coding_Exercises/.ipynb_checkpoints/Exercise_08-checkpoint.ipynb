# %% [markdown]
# # Coding Exercises (Part 1)

# %% [markdown]
# Now, you will have the opportunity to analyze your own dataset. <br>
# __Follow the instructions__ and insert your code! You are either requested to
# - Complete the Code and __Fill in the gaps__. Gaps are marked with "__---__" and are __placeholders__ for your code fragment.
# - Write Code completely __on your own__

# %% [markdown]
# In some exercises, you will find questions that can only be answered, if your code is correct and returns the right output! The correct answer is provided below your coding cell. There you can check whether your code is correct.

# %% [markdown]
# If you need a hint, check the __Hints Section__ at the end of this Notebook. Exercises and Hints are numerated accordingly.

# %% [markdown]
# If you need some further help or if you want to check your code, you can also watch the __solutions videos__ or check the __solutions notebook__.

# %% [markdown]
# ### Have Fun!

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## DataFrame Basics III

# %% [markdown]
# ### Exercise 8: apply(), MultiIndex and Strings

# %%
# run the cell!
import pandas as pd

# %%
# run the cell!
cars = pd.read_csv("cars.csv")

# %%
# run the cell!
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa             chevrolet s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# 61. __Calculate__ for all __numerical columns__ the __range between highest and lowest__ value! __Fill in the gaps!__ The range for __mpg__ is...?

# %%
cars.iloc[:, :-2].apply(lambda x: x.max() - x.min(), axis = 0)
# Out:
# mpg               37.6
# cylinders          5.0
# displacement     387.0
# horsepower       184.0
# weight          3527.0
# acceleration      16.8
# model_year        12.0
# dtype: float64

# %% [markdown]
# The range for mpg is ... 37.6!

# %% [markdown]
# 62. Create a __MultiIndex__ for the __cars__ DataFrame with the columns __"model_year"__ (outer level) and __"origin"__ (inner level). __Save__ the change!

# %%
cars.reset_index(inplace=True)
cars.set_index(["model_year", "origin"], inplace=True)
cars
# Out:
#                    index   mpg  cylinders  displacement  horsepower  weight  \
# model_year origin
# 70         usa         0  18.0          8         307.0       130.0    3504
#            usa         1  15.0          8         350.0       165.0    3693
#            usa         2  18.0          8         318.0       150.0    3436
#            usa         3  16.0          8         304.0       150.0    3433
#            usa         4  17.0          8         302.0       140.0    3449
# ...                  ...   ...        ...           ...         ...     ...
# 82         usa       393  27.0          4         140.0        86.0    2790
#            europe    394  44.0          4          97.0        52.0    2130
#            usa       395  32.0          4         135.0        84.0    2295
#            usa       396  28.0          4         120.0        79.0    2625
#            usa       397  31.0          4         119.0        82.0    2720
#
#                    acceleration                       name
# model_year origin
# 70         usa             12.0  chevrolet chevelle malibu
#            usa             11.5          buick skylark 320
#            usa             11.0         plymouth satellite
#            usa             12.0              amc rebel sst
#            usa             10.5                ford torino
# ...                         ...                        ...
# 82         usa             15.6            ford mustang gl
#            europe          24.6                  vw pickup
#            usa             11.6              dodge rampage
#            usa             18.6                ford ranger
#            usa             19.4             chevrolet s-10
#
# [398 rows x 8 columns]

# %% [markdown]
# 63. __Sort__ both index levels in __ascending__ order!. __Save__ the change!

# %%
cars.sort_index(ascending=True, inplace=True)

# %% [markdown]
# __Inspect__ Cars! What is the __name__ of the __second__ car?

# %%
# run the cell!
cars
# Out:
#                    index   mpg  cylinders  displacement  horsepower  weight  \
# model_year origin
# 70         europe     19  26.0          4          97.0        46.0    1835
#            europe     20  25.0          4         110.0        87.0    2672
#            europe     21  24.0          4         107.0        90.0    2430
#            europe     22  25.0          4         104.0        95.0    2375
#            europe     23  26.0          4         121.0       113.0    2234
# ...                  ...   ...        ...           ...         ...     ...
# 82         usa       392  27.0          4         151.0        90.0    2950
#            usa       393  27.0          4         140.0        86.0    2790
#            usa       395  32.0          4         135.0        84.0    2295
#            usa       396  28.0          4         120.0        79.0    2625
#            usa       397  31.0          4         119.0        82.0    2720
#
#                    acceleration                  name
# model_year origin
# 70         europe          20.5  vw 1131 deluxe sedan
#            europe          17.5           peugeot 504
#            europe          14.5           audi 100 ls
#            europe          17.5              saab 99e
#            europe          12.5              bmw 2002
# ...                         ...                   ...
# 82         usa             17.3      chevrolet camaro
#            usa             15.6       ford mustang gl
#            usa             11.6         dodge rampage
#            usa             18.6           ford ranger
#            usa             19.4        chevrolet s-10
#
# [398 rows x 8 columns]

# %% [markdown]
# The name of the second car is ... peugeot 504!

# %% [markdown]
# 64. __Select__ all cars with the "model_year" __75__!

# %%
cars.loc[75]
# Out:
#         index   mpg  cylinders  displacement  horsepower  weight  \
# origin
# europe    172  25.0          4          90.0        71.0    2223
# europe    175  29.0          4          90.0        70.0    1937
# europe    177  23.0          4         115.0        95.0    2694
# europe    178  23.0          4         120.0        88.0    2957
# europe    179  22.0          4         121.0        98.0    2945
# europe    180  25.0          4         121.0       115.0    2671
# japan     167  29.0          4          97.0        75.0    2171
# japan     171  24.0          4         134.0        96.0    2702
# japan     173  24.0          4         119.0        97.0    2545
# japan     181  33.0          4          91.0        53.0    1795
# usa       152  19.0          6         225.0        95.0    3264
# usa       153  18.0          6         250.0       105.0    3459
# usa       154  15.0          6         250.0        72.0    3432
# usa       155  15.0          6         250.0        72.0    3158
# usa       156  16.0          8         400.0       170.0    4668
# usa       157  15.0          8         350.0       145.0    4440
# usa       158  16.0          8         318.0       150.0    4498
# usa       159  14.0          8         351.0       148.0    4657
# usa       160  17.0          6         231.0       110.0    3907
# usa       161  16.0          6         250.0       105.0    3897
# usa       162  15.0          6         258.0       110.0    3730
# usa       163  18.0          6         225.0        95.0    3785
# usa       164  21.0          6         231.0       110.0    3039
# usa       165  20.0          8         262.0       110.0    3221
# usa       166  13.0          8         302.0       129.0    3169
# usa       168  23.0          4         140.0        83.0    2639
# usa       169  20.0          6         232.0       100.0    2914
# usa       170  23.0          4         140.0        78.0    2592
# usa       174  18.0          6         171.0        97.0    2984
# usa       176  19.0          6         232.0        90.0    3211
#
#         acceleration                       name
# origin
# europe          16.5                  vw dasher
# europe          14.0                  vw rabbit
# europe          15.0                 audi 100ls
# europe          17.0                peugeot 504
# europe          14.5                volvo 244dl
# europe          13.5                  saab 99le
# japan           16.0             toyota corolla
# japan           13.5              toyota corona
# japan           17.0                 datsun 710
# japan           17.5           honda civic cvcc
# usa             16.0    plymouth valiant custom
# usa             16.0             chevrolet nova
# usa             21.0            mercury monarch
# usa             19.5              ford maverick
# usa             11.5           pontiac catalina
# usa             14.0          chevrolet bel air
# usa             14.5        plymouth grand fury
# usa             13.5                   ford ltd
# usa             21.0              buick century
# usa             18.5  chevrolet chevelle malibu
# usa             19.0                amc matador
# usa             19.0              plymouth fury
# usa             15.0              buick skyhawk
# usa             13.5        chevrolet monza 2+2
# usa             12.0            ford mustang ii
# usa             17.0                 ford pinto
# usa             16.0                amc gremlin
# usa             18.5              pontiac astro
# usa             14.5                 ford pinto
# usa             17.0                  amc pacer

# %% [markdown]
# 65. __Select__ all cars with the "model_year" __76__ from __japan__! __How many__ cars do we get?

# %%
cars.loc[76, "japan"]
# Out:
#                    index   mpg  cylinders  displacement  horsepower  weight  \
# model_year origin
# 76         japan     198  33.0          4          91.0        53.0    1795
#            japan     204  32.0          4          85.0        70.0    1990
#            japan     205  28.0          4          97.0        75.0    2155
#            japan     210  19.0          6         156.0       108.0    2930
#
#                    acceleration            name
# model_year origin
# 76         japan           17.4     honda civic
#            japan           17.0    datsun b-210
#            japan           16.4  toyota corolla
#            japan           15.5  toyota mark ii

# %% [markdown]
# There are ... 4 cars!

# %% [markdown]
# 66. __Select__ all cars with the "model_year" __77__ and __79__  from __japan__! And only the columns __"mpg"__ and __"name"__! What is the __mpg__ of __datsun 210__?

# %%
cars.loc[([77, 79], "japan"), ["mpg", "name"]]
# Out:
#                     mpg                     name
# model_year origin
# 77         japan   31.5        honda accord cvcc
#            japan   33.5    datsun f-10 hatchback
#            japan   26.0  toyota corolla liftback
#            japan   30.0                subaru dl
#            japan   22.0               datsun 810
#            japan   21.5               mazda rx-4
# 79         japan   34.1         mazda glc deluxe
#            japan   31.8               datsun 210

# %% [markdown]
# The mpg of datsun 210 is ... 31.8!

# %% [markdown]
# 67. __Swap the levels__ of the MultiIndex and then __sort__ the new MultiIndex in __ascending__ order! __Reassign cars__! __Fill in the gaps__!

# %%
cars = cars.swaplevel().sort_index(ascending=True)

# %%
# run the cell!
cars
# Out:
#                    index   mpg  cylinders  displacement  horsepower  weight  \
# origin model_year
# europe 70             19  26.0          4          97.0        46.0    1835
#        70             20  25.0          4         110.0        87.0    2672
#        70             21  24.0          4         107.0        90.0    2430
#        70             22  25.0          4         104.0        95.0    2375
#        70             23  26.0          4         121.0       113.0    2234
# ...                  ...   ...        ...           ...         ...     ...
# usa    82            392  27.0          4         151.0        90.0    2950
#        82            393  27.0          4         140.0        86.0    2790
#        82            395  32.0          4         135.0        84.0    2295
#        82            396  28.0          4         120.0        79.0    2625
#        82            397  31.0          4         119.0        82.0    2720
#
#                    acceleration                  name
# origin model_year
# europe 70                  20.5  vw 1131 deluxe sedan
#        70                  17.5           peugeot 504
#        70                  14.5           audi 100 ls
#        70                  17.5              saab 99e
#        70                  12.5              bmw 2002
# ...                         ...                   ...
# usa    82                  17.3      chevrolet camaro
#        82                  15.6       ford mustang gl
#        82                  11.6         dodge rampage
#        82                  18.6           ford ranger
#        82                  19.4        chevrolet s-10
#
# [398 rows x 8 columns]

# %% [markdown]
# 68. __Reset__ the __index__ of __cars__ and create a RangeIndex! __Save__ the change!

# %%
cars.reset_index(inplace=True)

# %%
# run the cell!
cars
# Out:
#      origin  model_year  index   mpg  cylinders  displacement  horsepower  \
# 0    europe          70     19  26.0          4          97.0        46.0
# 1    europe          70     20  25.0          4         110.0        87.0
# 2    europe          70     21  24.0          4         107.0        90.0
# 3    europe          70     22  25.0          4         104.0        95.0
# 4    europe          70     23  26.0          4         121.0       113.0
# ..      ...         ...    ...   ...        ...           ...         ...
# 393     usa          82    392  27.0          4         151.0        90.0
# 394     usa          82    393  27.0          4         140.0        86.0
# 395     usa          82    395  32.0          4         135.0        84.0
# 396     usa          82    396  28.0          4         120.0        79.0
# 397     usa          82    397  31.0          4         119.0        82.0
#
#      weight  acceleration                  name
# 0      1835          20.5  vw 1131 deluxe sedan
# 1      2672          17.5           peugeot 504
# 2      2430          14.5           audi 100 ls
# 3      2375          17.5              saab 99e
# 4      2234          12.5              bmw 2002
# ..      ...           ...                   ...
# 393    2950          17.3      chevrolet camaro
# 394    2790          15.6       ford mustang gl
# 395    2295          11.6         dodge rampage
# 396    2625          18.6           ford ranger
# 397    2720          19.4        chevrolet s-10
#
# [398 rows x 10 columns]

# %% [markdown]
# 69. __Convert__ all elements in the __origin__ column to __titlecase__! __Overwrite__ the __origin__ column!

# %%
cars.origin = cars.origin.str.title()

# %%
# run the cell!
cars
# Out:
#      origin  model_year  index   mpg  cylinders  displacement  horsepower  \
# 0    Europe          70     19  26.0          4          97.0        46.0
# 1    Europe          70     20  25.0          4         110.0        87.0
# 2    Europe          70     21  24.0          4         107.0        90.0
# 3    Europe          70     22  25.0          4         104.0        95.0
# 4    Europe          70     23  26.0          4         121.0       113.0
# ..      ...         ...    ...   ...        ...           ...         ...
# 393     Usa          82    392  27.0          4         151.0        90.0
# 394     Usa          82    393  27.0          4         140.0        86.0
# 395     Usa          82    395  32.0          4         135.0        84.0
# 396     Usa          82    396  28.0          4         120.0        79.0
# 397     Usa          82    397  31.0          4         119.0        82.0
#
#      weight  acceleration                  name
# 0      1835          20.5  vw 1131 deluxe sedan
# 1      2672          17.5           peugeot 504
# 2      2430          14.5           audi 100 ls
# 3      2375          17.5              saab 99e
# 4      2234          12.5              bmw 2002
# ..      ...           ...                   ...
# 393    2950          17.3      chevrolet camaro
# 394    2790          15.6       ford mustang gl
# 395    2295          11.6         dodge rampage
# 396    2625          18.6           ford ranger
# 397    2720          19.4        chevrolet s-10
#
# [398 rows x 10 columns]

# %% [markdown]
# Now, we want to __extract the manufacturer names__ from the column __"name"__. <br>
# 70. __Split__ the strings in the column __"name"__ on the very __first whitespace__ and __expand__ the splitted strings into __separate columns__! __Save__ new DataFrame in the variable __split__! __Fill in the gaps!__

# %%
split = cars.name.str.split(pat = " ", n = 1, expand = True)

# %% [markdown]
# __Inspect__!

# %%
# run the cell!
split
# Out:
#              0                  1
# 0           vw  1131 deluxe sedan
# 1      peugeot                504
# 2         audi             100 ls
# 3         saab                99e
# 4          bmw               2002
# ..         ...                ...
# 393  chevrolet             camaro
# 394       ford         mustang gl
# 395      dodge            rampage
# 396       ford             ranger
# 397  chevrolet               s-10
#
# [398 rows x 2 columns]

# %% [markdown]
# 71. __Select__ the __first column__ and determine the __frequency of unique values__. __Fill in the gaps__! Which manufacturer is __most frequent__?

# %%
split[0].value_counts()
# Out:
# ford             51
# chevrolet        47
# plymouth         31
# amc              28
# dodge            28
# toyota           26
# datsun           23
# vw               22
# buick            17
# pontiac          16
# honda            13
# mercury          12
# mazda            12
# oldsmobile       10
# peugeot           8
# fiat              8
# audi              7
# volvo             6
# chrysler          6
# renault           5
# subaru            4
# saab              4
# opel              4
# mercedes-benz     3
# bmw               2
# cadillac          2
# triumph           1
# ih                1
# nissan            1
# Name: 0, dtype: int64

# %% [markdown]
# There are 51 cars from the manufacturer ... Ford!

# %% [markdown]
# 72. Let´s __doublecheck__ the result from above. Check __how many__ car names in the column "names" __contain "ford"__!

# %%
cars.name.str.contains("ford").sum()
# Out:
# 51

# %% [markdown]
# It´s ... again 51! It seems that the very first word in the column "name" is always the manufacturer name.

# %% [markdown]
# # Well Done!

# %% [markdown]
# ------------------------------

# %% [markdown]
# # Hints (Spoiler!)

# %% [markdown]
# 61. apply() method, maximum - minimum

# %% [markdown]
# 62. set_index() method, pass list with column labels

# %% [markdown]
# 63. sort_index() method

# %% [markdown]
# 64. pass outer index labels to loc operator

# %% [markdown]
# 65. cars.loc[(outer index labels, inner index labels)]

# %% [markdown]
# 66. cars.loc[(outer index labels, inner index labels), column labels]

# %% [markdown]
# 67. methods swaplevel() and sort_index()

# %% [markdown]
# 68. reset_index() method

# %% [markdown]
# 69. string(str)-method title()

# %% [markdown]
# 70. string(str)-method split(), n = 1,

# %% [markdown]
# 71. value_counts() method

# %% [markdown]
# 72. string(str)-method contains()
