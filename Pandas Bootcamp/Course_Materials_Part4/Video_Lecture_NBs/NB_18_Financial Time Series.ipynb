# %% [markdown]
# # Part 4: Managing Time Series Data With Pandas

# %% [markdown]
# ## Time Series Advanced / Financial Data

# %% [markdown]
# ### Importing and Exporting Stock Price Data from Yahoo Finance

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = ["AAPL", "BA", "KO", "IBM", "DIS", "MSFT" ]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2019-02-06")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-12-31  6.482683  42.180115  28.090706  91.445862  20.084139  23.684755
# 2010-01-04  6.583586  43.777542  27.933924  92.528694  20.098238  24.049969
# 2010-01-05  6.594968  45.211330  27.864237  91.410950  19.855110  24.057743
# 2010-01-06  6.490066  46.582798  27.716166  90.817116  19.848063  23.910097
# 2010-01-07  6.478067  48.468555  27.724878  90.502762  19.798731  23.661432
#
#                Close                                ...   Open              \
#                 AAPL         BA    DIS         IBM  ...    DIS         IBM
# Date                                                ...
# 2009-12-31  7.526071  54.130001  32.25  130.899994  ...  32.27  132.410004
# 2010-01-04  7.643214  56.180000  32.07  132.449997  ...  32.50  131.179993
# 2010-01-05  7.656429  58.020000  31.99  130.850006  ...  32.07  131.679993
# 2010-01-06  7.534643  59.779999  31.82  130.000000  ...  31.90  130.679993
# 2010-01-07  7.520714  62.200001  31.83  129.550003  ...  31.77  129.869995
#
#                                      Volume                               \
#                    KO       MSFT       AAPL        BA       DIS      IBM
# Date
# 2009-12-31  28.790001  30.980000  352410800   2189400  19651700  4223400
# 2010-01-04  28.580000  30.620001  493729600   6186700  13700400  6155300
# 2010-01-05  28.424999  30.850000  601904800   8867800  10307700  6841400
# 2010-01-06  28.174999  30.879999  552160000   8836500  10709500  5605300
# 2010-01-07  28.165001  30.629999  477131200  14379100   8202100  5840600
#
#
#                   KO      MSFT
# Date
# 2009-12-31  10848800  31929700
# 2010-01-04  13870400  38409100
# 2010-01-05  23172400  49749600
# 2010-01-06  19264600  58182400
# 2010-01-07  13234600  50559700
#
# [5 rows x 36 columns]

# %%
stocks.tail()
# Out:
#             Adj Close                                                 \
#                  AAPL          BA         DIS         IBM         KO
# Date
# 2019-01-30  40.292267  376.746277  108.800331  120.233337  44.484833
# 2019-01-31  40.582428  374.705688  110.173546  120.269112  44.735794
# 2019-02-01  40.601936  376.464508  109.956207  119.982819  45.265602
# 2019-02-04  41.755226  385.763641  110.450172  120.958046  45.776814
# 2019-02-05  42.469643  398.570557  111.299789  121.280167  45.786098
#
#                             Close                                      ...  \
#                   MSFT       AAPL          BA         DIS         IBM  ...
# Date                                                                   ...
# 2019-01-30  103.492729  41.312500  387.720001  110.129997  134.380005  ...
# 2019-01-31  101.595657  41.610001  385.619995  111.519997  134.419998  ...
# 2019-02-01   99.990440  41.630001  387.429993  111.300003  134.100006  ...
# 2019-02-04  102.870094  42.812500  397.000000  111.800003  135.190002  ...
# 2019-02-05  104.309929  43.544998  410.179993  112.660004  135.550003  ...
#
#                   Open                                        Volume  \
#                    DIS         IBM         KO        MSFT       AAPL
# Date
# 2019-01-30  110.300003  134.000000  47.250000  104.620003  244439200
# 2019-01-31  110.099998  134.449997  47.849998  103.800003  162958400
# 2019-02-01  111.970001  134.970001  48.480000  103.779999  130672400
# 2019-02-04  111.410004  134.020004  48.700001  102.870003  125982000
# 2019-02-05  112.019997  135.279999  49.330002  106.059998  144406400
#
#
#                   BA       DIS      IBM        KO      MSFT
# Date
# 2019-01-30  12705300   7853800  4500900  12952500  49471900
# 2019-01-31   6878500   8351600  4884000  32181500  55636400
# 2019-02-01   5625700   6557700  3806000  19130100  35535700
# 2019-02-04   4256600   7037000  3966600  15105700  31315100
# 2019-02-05   7230400  13619800  5398900  12651900  27325400
#
# [5 rows x 36 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2289 entries, 2009-12-31 to 2019-02-05
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2289 non-null   float64
#  1   (Adj Close, BA)    2289 non-null   float64
#  2   (Adj Close, DIS)   2289 non-null   float64
#  3   (Adj Close, IBM)   2289 non-null   float64
#  4   (Adj Close, KO)    2289 non-null   float64
#  5   (Adj Close, MSFT)  2289 non-null   float64
#  6   (Close, AAPL)      2289 non-null   float64
#  7   (Close, BA)        2289 non-null   float64
#  8   (Close, DIS)       2289 non-null   float64
#  9   (Close, IBM)       2289 non-null   float64
#  10  (Close, KO)        2289 non-null   float64
#  11  (Close, MSFT)      2289 non-null   float64
#  12  (High, AAPL)       2289 non-null   float64
#  13  (High, BA)         2289 non-null   float64
#  14  (High, DIS)        2289 non-null   float64
#  15  (High, IBM)        2289 non-null   float64
#  16  (High, KO)         2289 non-null   float64
#  17  (High, MSFT)       2289 non-null   float64
#  18  (Low, AAPL)        2289 non-null   float64
#  19  (Low, BA)          2289 non-null   float64
#  20  (Low, DIS)         2289 non-null   float64
#  21  (Low, IBM)         2289 non-null   float64
#  22  (Low, KO)          2289 non-null   float64
#  23  (Low, MSFT)        2289 non-null   float64
#  24  (Open, AAPL)       2289 non-null   float64
#  25  (Open, BA)         2289 non-null   float64
#  26  (Open, DIS)        2289 non-null   float64
#  27  (Open, IBM)        2289 non-null   float64
#  28  (Open, KO)         2289 non-null   float64
#  29  (Open, MSFT)       2289 non-null   float64
#  30  (Volume, AAPL)     2289 non-null   int64
#  31  (Volume, BA)       2289 non-null   int64
#  32  (Volume, DIS)      2289 non-null   int64
#  33  (Volume, IBM)      2289 non-null   int64
#  34  (Volume, KO)       2289 non-null   int64
#  35  (Volume, MSFT)     2289 non-null   int64
# dtypes: float64(30), int64(6)
# memory usage: 661.7 KB

# %%
stocks.to_csv("stocks.csv")

# %%
stocks = pd.read_csv("stocks.csv", header = [0, 1], index_col = [0], parse_dates = [0])

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-12-31  6.482683  42.180115  28.090706  91.445862  20.084139  23.684755
# 2010-01-04  6.583586  43.777542  27.933924  92.528694  20.098238  24.049969
# 2010-01-05  6.594968  45.211330  27.864237  91.410950  19.855110  24.057743
# 2010-01-06  6.490066  46.582798  27.716166  90.817116  19.848063  23.910097
# 2010-01-07  6.478067  48.468555  27.724878  90.502762  19.798731  23.661432
#
#                Close                                ...   Open              \
#                 AAPL         BA    DIS         IBM  ...    DIS         IBM
# Date                                                ...
# 2009-12-31  7.526071  54.130001  32.25  130.899994  ...  32.27  132.410004
# 2010-01-04  7.643214  56.180000  32.07  132.449997  ...  32.50  131.179993
# 2010-01-05  7.656429  58.020000  31.99  130.850006  ...  32.07  131.679993
# 2010-01-06  7.534643  59.779999  31.82  130.000000  ...  31.90  130.679993
# 2010-01-07  7.520714  62.200001  31.83  129.550003  ...  31.77  129.869995
#
#                                      Volume                               \
#                    KO       MSFT       AAPL        BA       DIS      IBM
# Date
# 2009-12-31  28.790001  30.980000  352410800   2189400  19651700  4223400
# 2010-01-04  28.580000  30.620001  493729600   6186700  13700400  6155300
# 2010-01-05  28.424999  30.850000  601904800   8867800  10307700  6841400
# 2010-01-06  28.174999  30.879999  552160000   8836500  10709500  5605300
# 2010-01-07  28.165001  30.629999  477131200  14379100   8202100  5840600
#
#
#                   KO      MSFT
# Date
# 2009-12-31  10848800  31929700
# 2010-01-04  13870400  38409100
# 2010-01-05  23172400  49749600
# 2010-01-06  19264600  58182400
# 2010-01-07  13234600  50559700
#
# [5 rows x 36 columns]

# %%
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'BA'),  ('Adj Close', 'DIS'),
#         ('Adj Close', 'IBM'),   ('Adj Close', 'KO'), ('Adj Close', 'MSFT'),
#            ('Close', 'AAPL'),       ('Close', 'BA'),      ('Close', 'DIS'),
#             ('Close', 'IBM'),       ('Close', 'KO'),     ('Close', 'MSFT'),
#             ('High', 'AAPL'),        ('High', 'BA'),       ('High', 'DIS'),
#              ('High', 'IBM'),        ('High', 'KO'),      ('High', 'MSFT'),
#              ('Low', 'AAPL'),         ('Low', 'BA'),        ('Low', 'DIS'),
#               ('Low', 'IBM'),         ('Low', 'KO'),       ('Low', 'MSFT'),
#             ('Open', 'AAPL'),        ('Open', 'BA'),       ('Open', 'DIS'),
#              ('Open', 'IBM'),        ('Open', 'KO'),      ('Open', 'MSFT'),
#           ('Volume', 'AAPL'),      ('Volume', 'BA'),     ('Volume', 'DIS'),
#            ('Volume', 'IBM'),      ('Volume', 'KO'),    ('Volume', 'MSFT')],
#       dtype='object')

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-12-31  6.482683  42.180115  28.090706  91.445862  20.084139  23.684755
# 2010-01-04  6.583586  43.777542  27.933924  92.528694  20.098238  24.049969
# 2010-01-05  6.594968  45.211330  27.864237  91.410950  19.855110  24.057743
# 2010-01-06  6.490066  46.582798  27.716166  90.817116  19.848063  23.910097
# 2010-01-07  6.478067  48.468555  27.724878  90.502762  19.798731  23.661432
#
#                Close                                ...   Open              \
#                 AAPL         BA    DIS         IBM  ...    DIS         IBM
# Date                                                ...
# 2009-12-31  7.526071  54.130001  32.25  130.899994  ...  32.27  132.410004
# 2010-01-04  7.643214  56.180000  32.07  132.449997  ...  32.50  131.179993
# 2010-01-05  7.656429  58.020000  31.99  130.850006  ...  32.07  131.679993
# 2010-01-06  7.534643  59.779999  31.82  130.000000  ...  31.90  130.679993
# 2010-01-07  7.520714  62.200001  31.83  129.550003  ...  31.77  129.869995
#
#                                      Volume                               \
#                    KO       MSFT       AAPL        BA       DIS      IBM
# Date
# 2009-12-31  28.790001  30.980000  352410800   2189400  19651700  4223400
# 2010-01-04  28.580000  30.620001  493729600   6186700  13700400  6155300
# 2010-01-05  28.424999  30.850000  601904800   8867800  10307700  6841400
# 2010-01-06  28.174999  30.879999  552160000   8836500  10709500  5605300
# 2019-02-05  104.309929  43.544998  410.179993  112.660004  135.550003  ...
#
#                   Open                                        Volume  \
#                    DIS         IBM         KO        MSFT       AAPL
# Date
# 2019-01-30  110.300003  134.000000  47.250000  104.620003  244439200
# 2019-01-31  110.099998  134.449997  47.849998  103.800003  162958400
# 2019-02-01  111.970001  134.970001  48.480000  103.779999  130672400
# 2019-02-04  111.410004  134.020004  48.700001  102.870003  125982000
# 2019-02-05  112.019997  135.279999  49.330002  106.059998  144406400
#
#
#                   BA       DIS      IBM        KO      MSFT
# Date
# 2019-01-30  12705300   7853800  4500900  12952500  49471900
# 2019-01-31   6878500   8351600  4884000  32181500  55636400
# 2019-02-01   5625700   6557700  3806000  19130100  35535700
# 2019-02-04   4256600   7037000  3966600  15105700  31315100
# 2019-02-05   7230400  13619800  5398900  12651900  27325400
#
# [5 rows x 36 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2289 entries, 2009-12-31 to 2019-02-05
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2289 non-null   float64
#  1   (Adj Close, BA)    2289 non-null   float64
#  2   (Adj Close, DIS)   2289 non-null   float64
#  3   (Adj Close, IBM)   2289 non-null   float64
#  4   (Adj Close, KO)    2289 non-null   float64
#  5   (Adj Close, MSFT)  2289 non-null   float64
#  6   (Close, AAPL)      2289 non-null   float64
#  7   (Close, BA)        2289 non-null   float64
#  8   (Close, DIS)       2289 non-null   float64
#  9   (Close, IBM)       2289 non-null   float64
#  10  (Close, KO)        2289 non-null   float64
#  11  (Close, MSFT)      2289 non-null   float64
#  12  (High, AAPL)       2289 non-null   float64
#  13  (High, BA)         2289 non-null   float64
#  14  (High, DIS)        2289 non-null   float64
#  15  (High, IBM)        2289 non-null   float64
#  16  (High, KO)         2289 non-null   float64
#  17  (High, MSFT)       2289 non-null   float64
#  18  (Low, AAPL)        2289 non-null   float64
#  19  (Low, BA)          2289 non-null   float64
#  20  (Low, DIS)         2289 non-null   float64
#  21  (Low, IBM)         2289 non-null   float64
#  22  (Low, KO)          2289 non-null   float64
#  23  (Low, MSFT)        2289 non-null   float64
#  24  (Open, AAPL)       2289 non-null   float64
#  25  (Open, BA)         2289 non-null   float64
#  26  (Open, DIS)        2289 non-null   float64
#  27  (Open, IBM)        2289 non-null   float64
#  28  (Open, KO)         2289 non-null   float64
#  29  (Open, MSFT)       2289 non-null   float64
#  30  (Volume, AAPL)     2289 non-null   int64
#  31  (Volume, BA)       2289 non-null   int64
#  32  (Volume, DIS)      2289 non-null   int64
#  33  (Volume, IBM)      2289 non-null   int64
#  34  (Volume, KO)       2289 non-null   int64
#  35  (Volume, MSFT)     2289 non-null   int64
# dtypes: float64(30), int64(6)
# memory usage: 661.7 KB

# %%
stocks.describe()
# Out:
#          Adj Close                                                      \
#               AAPL           BA          DIS          IBM           KO
# count  2289.000000  2289.000000  2289.000000  2289.000000  2289.000000
# mean     23.069882   130.148071    71.625703   126.885291    32.152466
# std      11.758983    88.687133    29.818073    16.959474     6.786859
# min       5.908031    42.180115    25.536150    85.500839    17.790277
# 25%      13.521920    60.512379    38.741524   118.516098    27.532042
# 50%      21.490923   111.240807    79.018356   129.013351    32.740440
# 75%      29.002626   135.348984    99.532654   140.112030    37.310146
# max      56.387985   398.570557   116.560318   159.538162    46.845711
#
#                           Close                                         ...  \
#               MSFT         AAPL           BA          DIS          IBM  ...
# count  2289.000000  2289.000000  2289.000000  2289.000000  2289.000000  ...
# mean     43.947906    25.003036   144.064513    76.563272   164.363194  ...
# std      25.090229    11.727062    88.321575    29.837647    24.157742  ...
# min      18.044788     6.858929    54.130001    29.000000   107.570000  ...
# 25%      23.572279    15.420357    73.739998    43.470001   145.990005  ...
# 50%      36.753197    23.747499   127.639999    85.860001   162.039993  ...
# 75%      54.549843    31.695000   152.250000   104.220001   185.919998  ...
# max     111.988419    58.017502   410.179993   121.690002   215.800003  ...
#
#               Open                                               Volume  \
#                DIS          IBM           KO         MSFT          AAPL
# count  2289.000000  2289.000000  2289.000000  2289.000000  2.289000e+03
# mean     76.558703   164.305963    39.367005    48.649244  3.187362e+08
# std      29.868884    24.143379     5.568519    24.463537  2.380407e+08
# min      28.730000   108.000000    25.110001    23.090000  4.590360e+07
# 25%      43.470001   146.000000    36.174999    28.969999  1.371600e+08
# 50%      86.000000   162.000000    40.689999    41.610001  2.498160e+08
# 75%     104.230003   185.600006    43.320000    58.650002  4.298896e+08
# max     121.500000   215.380005    50.820000   115.419998  1.880998e+09
#
#
#                  BA           DIS           IBM            KO          MSFT
# count  2.289000e+03  2.289000e+03  2.289000e+03  2.289000e+03  2.289000e+03
# mean   4.600220e+06  8.780499e+06  4.804254e+06  1.503044e+07  4.154675e+07
# std    2.440858e+06  4.912058e+06  2.526676e+06  6.573916e+06  2.338828e+07
# min    7.889000e+05  2.165700e+06  1.193000e+06  2.996300e+06  7.425600e+06
# 25%    3.108500e+06  6.056300e+06  3.310000e+06  1.082690e+07  2.590170e+07
# 50%    4.091200e+06  7.603600e+06  4.168400e+06  1.354870e+07  3.599450e+07
# 75%    5.331900e+06  9.949000e+06  5.398900e+06  1.754960e+07  5.159570e+07
# max    4.439180e+07  8.704850e+07  3.049020e+07  9.896750e+07  3.193179e+08
#
# [8 rows x 36 columns]

# %%
close = stocks.loc[:, "Close"].copy()

# %%
close.head()
# Out:
#                 AAPL         BA    DIS         IBM         KO       MSFT
# Date
# 2009-12-31  7.526071  54.130001  32.25  130.899994  28.500000  30.480000
# 2010-01-04  7.643214  56.180000  32.07  132.449997  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.99  130.850006  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.82  130.000000  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.83  129.550003  28.094999  30.450001

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
close.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ### Normalizing Time Series to a Base Value (100)

# %%
close.head()

# %%
close.iloc[0,0]

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)

# %%
close.iloc[0]

# %%
norm = close.div(close.iloc[0]).mul(100)
norm

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ### The shift() method

# %%
close.head()

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()

# %%
aapl.shift(periods = 1)

# %%
aapl["lag1"] = aapl.shift(periods = 1)

# %%
aapl.head()

# %%
aapl.AAPL.sub(aapl.lag1)

# %%
aapl["Diff"] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl.head()

# %%
aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl["pct_change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl.head()

# %% [markdown]
# ### The methods diff() and pct_change()

# %%
aapl.head()

# %%
aapl.AAPL.diff(periods = 2)

# %%
aapl["Diff2"] = aapl.AAPL.diff(periods = 1)

# %%
aapl.head(10)

# %%
aapl.Diff.equals(aapl.Diff2)

# %%
aapl["pct_change2"] = aapl.AAPL.pct_change(periods = 1).mul(100)

# %%
aapl.head()

# %%
aapl.AAPL.resample("BM").last().pct_change(periods =1).mul(100)

# %% [markdown]
# ### Measuring Stock Perfromance with MEAN Return and STD of Returns

# %%
import numpy as np

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()

# %%
aapl.pct_change().dropna()

# %%
ret = aapl.pct_change().dropna()
ret.head()

# %%
ret.info()

# %%
ret.plot(kind = "hist", figsize = (12 ,8), bins = 100)
plt.show()

# %%
daily_mean_Return = ret.mean()
daily_mean_Return

# %%
var_daily_Returns = ret.var()
var_daily_Returns

# %%
std_daily_Returns = np.sqrt(var_daily_Returns)
std_daily_Returns

# %%
ret.std()

# %%
ann_mean_Return = ret.mean() * 252
ann_mean_Return

# %%
ann_var_Returns = ret.var() * 252
ann_var_Returns

# %%
ann_std_Returns = np.sqrt(ann_var_Returns)
ann_std_Returns

# %%
ret.std() * np.sqrt(252)

# %% [markdown]
# ### Financial Time Series - Return and Risk

# %%
import numpy as np

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
close.head()

# %%
close.pct_change().dropna()

# %%
ret = close.pct_change().dropna()

# %%
ret.head()

# %%
ret.describe().T.loc[:, ["mean", "std"]]

# %%
summary = ret.describe().T.loc[:, ["mean", "std"]]
summary

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"] * np.sqrt(252)

# %%
summary

# %%
summary.plot(kind = "scatter", x = "std", y = "mean", figsize = (15,12), s = 50, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"]+0.002, summary.loc[i, "mean"]+0.002), size = 15)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %% [markdown]
# ### Financial Time Series - Covariance and Correlation

# %%
ret.head()

# %%
ret.cov()

# %%
ret.corr()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap = "Reds", annot = True, annot_kws={"size":15}, vmax = 0.6)
plt.show()

# %% [markdown]
# ### Helpful DatetimeIndex Attributes and Methods

# %%
import pandas as pd

# %%
stocks = pd.read_csv("stocks.csv", header = [0,1], index_col= [0], parse_dates= [0])

# %%
stocks.head()

# %%
close = stocks.loc[:, "Close"].copy()

# %%
close.head()

# %%
close.info()

# %%
close.index

# %%
close.index.day

# %%
close.index.month

# %%
close.index.year

# %%
close.index.day_name()

# %%
close.index.month_name()

# %%
 close.index.weekday

# %%
close.index.quarter

# %%
close.index.days_in_month

# %%
close.index.week

# %%
close.index.weekofyear

# %%
close.index.is_month_end

# %%
close["Day"] = stocks.index.day_name()
close["Quarter"] = stocks.index.quarter

# %%
close.head()

# %% [markdown]
# ### Filling NA Values with bfill, ffill and interpolation

# %%
close.head()

# %%
close.tail()

# %%
all_days = pd.date_range(start = "2009-12-31", end = "2019-02-06", freq = "D")
all_days

# %%
close = close.reindex(all_days)

# %%
close.head(20)

# %%
close.Day = close.index.day_name()
close.Quarter = close.index.quarter

# %%
close.fillna(method = "ffill", inplace= True)

# %%
close.head(15)

# %%
temp = pd.read_csv("temp.csv", parse_dates=["datetime"], index_col = "datetime")

# %%
temp.head(10)

# %%
temp = temp.resample("30 Min").mean()
temp.head(10)

# %%
temp.interpolate()
