# %% [markdown]
# # Initial Analysis

# %% [markdown]
# Using data previously created in "Data Compilation", file printed to csv according to last date stamp

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("30-04-2021.csv", index_col = ["date", "yahoo_index"])
data.head()
# Out:
#                        iso_code  total_cases_per_million  \
# date       yahoo_index
# 2020-01-02 ^MERV            ARG                      NaN
# 2020-01-03 ^MERV            ARG                      NaN
# 2020-01-06 ^MERV            ARG                      NaN
# 2020-01-07 ^MERV            ARG                      NaN
# 2020-01-08 ^MERV            ARG                      NaN
#
#                         new_cases_per_million  new_cases_smoothed_per_million  \
# date       yahoo_index
# 2020-01-02 ^MERV                          NaN                             NaN
# 2020-01-03 ^MERV                          NaN                             NaN
# 2020-01-06 ^MERV                          NaN                             NaN
# 2020-01-07 ^MERV                          NaN                             NaN
# 2020-01-08 ^MERV                          NaN                             NaN
#
#                         total_deaths_per_million  new_deaths_per_million  \
# date       yahoo_index
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 9105 entries, ('2020-01-02', '^MERV') to ('2021-04-29', '^VIX')
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   iso_code                             9105 non-null   object
#  1   total_cases_per_million              8906 non-null   float64
#  2   new_cases_per_million                8897 non-null   float64
#  3   new_cases_smoothed_per_million       8817 non-null   float64
#  4   total_deaths_per_million             8275 non-null   float64
#  5   new_deaths_per_million               8290 non-null   float64
#  6   new_deaths_smoothed_per_million      8817 non-null   float64
#  7   reproduction_rate                    7929 non-null   float64
#  8   population                           9105 non-null   float64
#  9   population_density                   8476 non-null   float64
# ...

# %%
data_subset1 = data.iloc[:, [1, 3, 4, 6, 10, 16]]

# %%
data_subset1.loc[:, "Close"].argmax()
# Out:
# 7137

# %%
data_subset1.iloc[data_subset1.loc[:, "Close"].argmax()]
# Out:
# total_cases_per_million            14.136000
# new_cases_smoothed_per_million      1.763000
# total_deaths_per_million            0.293000
# new_deaths_smoothed_per_million     0.032000
# total_vaccinations_per_hundred           NaN
# Close                               6.631115
# Name: (2020-03-16, ^VIX), dtype: float64

# %%
data_subset1.corr()
# Out:
#                                  total_cases_per_million  \
# total_cases_per_million                         1.000000
# new_cases_smoothed_per_million                  0.646774
# total_deaths_per_million                        0.889254
# new_deaths_smoothed_per_million                 0.531141
# total_vaccinations_per_hundred                  0.635066
# Close                                           0.198807
#
#                                  new_cases_smoothed_per_million  \
# total_cases_per_million                                0.646774
# new_cases_smoothed_per_million                         1.000000
# total_deaths_per_million                               0.569241
# new_deaths_smoothed_per_million                        0.686166
# total_vaccinations_per_hundred                        -0.017116
# Close                                                  0.126034
#
#                                  total_deaths_per_million  \
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")
data_subset1.loc[:, "Close"].unstack().plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
data_subset1 = data_subset1.reset_index()[data_subset1.reset_index().yahoo_index != "^VIX"]
data_subset1.set_index(["date", "yahoo_index"], inplace = True)

# %%
data_subset1
# Out:
#                         index  total_cases_per_million  \
# date       yahoo_index
# 2020-01-02 ^MERV            0                      NaN
# 2020-01-03 ^MERV            1                      NaN
# 2020-01-06 ^MERV            2                      NaN
# 2020-01-07 ^MERV            3                      NaN
# 2020-01-08 ^MERV            4                      NaN
# ...                       ...                      ...
# 2021-04-29 ^DJI          9099                97549.217
#            ^IXIC         9100                97549.217
#            ^NYA          9101                97549.217
#            ^XAX          9102                97549.217
#            ^RUT          9103                97549.217
#
#                         new_cases_smoothed_per_million  \
# date       yahoo_index
# 2020-01-02 ^MERV                                   NaN
# 2020-01-03 ^MERV                                   NaN
# 2020-01-06 ^MERV                                   NaN
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")
data_subset1.loc[:, "Close"].unstack().plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()
